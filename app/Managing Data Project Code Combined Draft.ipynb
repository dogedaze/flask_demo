# %% [markdown]
# # SANDY'S CODE

# %% [markdown]
# # SETTING UP THE DATA AND API

# %%
#SH
#pip install yfinance

# %%
#SH
import yfinance as yf #Allows us to Use Yahoo Finance API 
import pandas as pd
import numpy as np
import json

# %%
yf.Ticker('TSLA').info
# Out:
# {'zip': '78725',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 70757,
#  'longBusinessSummary': 'Tesla, Inc. designs, develops, manufactures, leases, and sells electric vehicles, and energy generation and storage systems in the United States, China, and internationally. The company operates in two segments, Automotive, and Energy Generation and Storage. The Automotive segment offers electric vehicles, as well as sells automotive regulatory credits. It provides sedans and sport utility vehicles through direct and used vehicle sales, a network of Tesla Superchargers, and in-app upgrades; and purchase financing and leasing services. This segment is also involved in the provision of non-warranty after-sales vehicle services, sale of used vehicles, retail merchandise, and vehicle insurance, as well as sale of products through its subsidiaries to third party customers; services for electric vehicles through its company-owned service locations, and Tesla mobile service technicians; and vehicle limited warranties and extended service plans. The Energy Generation and Storage segment engages in the design, manufacture, installation, sale, and leasing of solar energy generation and energy storage products, and related services to residential, commercial, and industrial customers and utilities through its website, stores, and galleries, as well as through a network of channel partners. This segment also offers service and repairs to its energy product customers, including under warranty; and various financing options to its solar customers. The company was formerly known as Tesla Motors, Inc. and changed its name to Tesla, Inc. in February 2017. Tesla, Inc. was founded in 2003 and is headquartered in Austin, Texas.',
#  'city': 'Austin',
#  'phone': '650-681-5000',
#  'state': 'TX',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.tesla.com',
#  'maxAge': 1,
#  'address1': '13101 Harold Green Road',
#  'industry': 'Auto Manufacturers',
#  'ebitdaMargins': 0.15512,
#  'profitMargins': 0.07403,
#  'grossMargins': 0.23107,
#  'operatingCashflow': 9930999808,
#  'revenueGrowth': 0.568,
#  'operatingMargins': 0.09789,
#  'ebitda': 7266999808,
#  'targetLowPrice': 67,
#  'recommendationKey': 'hold',
#  'grossProfits': 6630000000,
#  'freeCashflow': 4644624896,
#  'targetMedianPrice': 950,
#  'currentPrice': 1070.25,
#  'earningsGrowth': 4.333,
#  'currentRatio': 1.385,
#  'returnOnAssets': 0.055370003,
#  'numberOfAnalystOpinions': 35,
#  'targetMeanPrice': 855.58,
#  'debtToEquity': 35.65,
#  'returnOnEquity': 0.15641,
#  'targetHighPrice': 1400,
#  'totalCash': 16094999552,
#  'totalDebt': 10158000128,
#  'totalRevenue': 46848000000,
#  'totalCashPerShare': 16.027,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 48.272,
#  'quickRatio': 1.002,
#  'recommendationMean': 2.6,
#  'exchange': 'NMS',
#  'shortName': 'Tesla, Inc.',
#  'longName': 'Tesla, Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'TSLA',
#  'messageBoardId': 'finmb_27444752',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 22.45,
#  'beta3Year': None,
#  'enterpriseToEbitda': 144.728,
#  '52WeekChange': 0.73992527,
#  'morningStarRiskRating': None,
#  'forwardEps': 8.19,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 1004259968,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 26.945,
#  'sharesShort': 25702669,
#  'sharesPercentSharesOut': 0.0256,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.42384997,
#  'netIncomeToCommon': 3468000000,
#  'trailingEps': 3.062,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.27606308,
#  'priceToBook': 39.7198,
#  'heldPercentInsiders': 0.19304001,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1632960000,
#  'shortRatio': 0.76,
#  'sharesShortPreviousMonthDate': 1634256000,
#  'floatShares': 815734211,
#  'beta': 2.037922,
#  'enterpriseValue': 1051739553792,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1598832000,
#  'lastSplitFactor': '5:1',
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 3.888,
#  'priceToSalesTrailing12Months': 22.942478,
#  'dateShortInterest': 1636934400,
#  'pegRatio': 2.38,
#  'ytdReturn': None,
#  'forwardPE': 130.67766,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0315,
#  'sharesShortPriorMonth': 30337020,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 1051.75,
#  'regularMarketOpen': 1052.71,
#  'twoHundredDayAverage': 753.3011,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 1072.38,
#  'navPrice': None,
#  'averageDailyVolume10Day': 24070920,
#  'regularMarketPreviousClose': 1051.75,
#  'fiftyDayAverage': 991.3784,
#  'trailingAnnualDividendRate': None,
#  'open': 1052.71,
#  'toCurrency': None,
#  'averageVolume10days': 24070920,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 1033.0001,
#  'currency': 'USD',
#  'trailingPE': 349.52646,
#  'regularMarketVolume': 12723305,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1074809208832,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 25575446,
#  'dayLow': 1033.0001,
#  'ask': 1070.28,
#  'askSize': 800,
#  'volume': 12723305,
#  'fiftyTwoWeekHigh': 1243.49,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 539.49,
#  'bid': 1069.55,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 900,
#  'dayHigh': 1072.38,
#  'regularMarketPrice': 1070.25,
#  'preMarketPrice': 1052.5,
#  'logo_url': 'https://logo.clearbit.com/tesla.com'}

# %%
#SH
#Function to Get Different Kinds Of Info From a Stock Ticker Directly Through API 

def ticker_info():
    ticker_name = input("Enter Ticker Name")
    ticker_symbol = yf.Ticker(ticker_name)
    ticker_data = ticker_symbol.history(period="max")
    return ticker_data

# %%
#SH
ticker_info()
# Out:
# Enter Ticker Name TSLA
#                    Open         High          Low        Close    Volume  \
# Date
# 2010-06-29     3.800000     5.000000     3.508000     4.778000  93831500
# 2010-06-30     5.158000     6.084000     4.660000     4.766000  85935500
# 2010-07-01     5.000000     5.184000     4.054000     4.392000  41094000
# 2010-07-02     4.600000     4.620000     3.742000     3.840000  25699000
# 2010-07-06     4.000000     4.000000     3.166000     3.222000  34334500
# ...                 ...          ...          ...          ...       ...
# 2021-12-02  1099.060059  1113.000000  1056.650024  1084.599976  24371600
# 2021-12-03  1084.790039  1090.579956  1000.210022  1014.969971  30696300
# 2021-12-06  1001.510010  1021.640015   950.500000  1009.010010  27221000
# 2021-12-07  1044.199951  1057.670044  1026.810059  1051.750000  18694900
# 2021-12-08  1052.709961  1072.380005  1033.000122  1070.060059  12725740
#
#             Dividends  Stock Splits
# Date
# 2010-06-29          0           0.0
# 2010-06-30          0           0.0
# 2010-07-01          0           0.0
# 2010-07-02          0           0.0
# 2010-07-06          0           0.0
# ...               ...           ...
# 2021-12-02          0           0.0
# 2021-12-03          0           0.0
# 2021-12-06          0           0.0
# 2021-12-07          0           0.0
# 2021-12-08          0           0.0
#
# [2883 rows x 7 columns]

# %%
#SH
#Function to Pull Current Price from a Stock Ticker Directly Through API

def current_ticker_price():
    ticker_name = input("Enter Ticker Name")
    ticker_symbol = yf.Ticker(ticker_name)
    ticker_data = ticker_symbol.history(period="min")
    ticker_open = ticker_data.filter(['Open'])
    ticker_open = ticker_open.rename(columns = {"Open": ticker_name}) 
    print(ticker_open)

# %%
#SH
current_ticker_price()
# Out:
# Enter Ticker Name TSLA
#                    TSLA
# Date
# 2021-12-08  1052.709961

# %% [markdown]
# # SETTING UP SAMPLE DATA FOR STOCKS

# %%
#SH
#Setting Up the Sample Data For Stocks

#Pulling Stocks from Stock Using Ticker API
msft = yf.Ticker("MSFT")
aapl = yf.Ticker("AAPL")
tsla = yf.Ticker("TSLA")
sony = yf.Ticker("SONY")
mcd = yf.Ticker("MCD")
fb = yf.Ticker("FB")
jpm = yf.Ticker("JPM")
dis = yf.Ticker("DIS")
cost = yf.Ticker("COST")
cvs = yf.Ticker("CVS")
nflx = yf.Ticker("NFLX")
sbux = yf.Ticker("SBUX")
uber = yf.Ticker("UBER")
nke = yf.Ticker("NKE")
amzn = yf.Ticker("AMZN")
pfe = yf.Ticker("PFE")
googl = yf.Ticker("GOOGL")
lrlcy = yf.Ticker("LRLCY")
dell = yf.Ticker("DELL")
unh = yf.Ticker("UNH")

# %%
#SH
#Getting aLl the history
msft_data = msft.history(period="max")
aapl_data = aapl.history(period="max")
tsla_data = tsla.history(period="max")
sony_data = sony.history(period="max")
mcd_data = mcd.history(period="max")
fb_data = fb.history(period="max")
jpm_data = jpm.history(period="max")
dis_data = dis.history(period="max")
cost_data = cost.history(period="max")
cvs_data = cvs.history(period="max")
nflx_data = nflx.history(period="max")
sbux_data = sbux.history(period="max")
uber_data = uber.history(period="max")
nke_data = nke.history(period="max")
amzn_data = amzn.history(period="max")
pfe_data = pfe.history(period="max")
googl_data = googl.history(period="max")
lrlcy_data = lrlcy.history(period="max")
dell_data = dell.history(period="max")
unh_data = unh.history(period="max")

# %%
#SH
#Filtering For One Type of Price (Open)
msft_open = msft_data.filter(['Open'])
aapl_open = aapl_data.filter(['Open'])
tsla_open = tsla_data.filter(['Open'])
sony_open = sony_data.filter(['Open'])
mcd_open = mcd_data.filter(['Open'])
fb_open = fb_data.filter(['Open'])
jpm_open = jpm_data.filter(['Open'])
dis_open = dis_data.filter(['Open'])
cost_open = cost_data.filter(['Open'])
cvs_open = cvs_data.filter(['Open'])
nflx_open = nflx_data.filter(['Open'])
sbux_open = sbux_data.filter(['Open'])
uber_open = uber_data.filter(['Open'])
nke_open = nke_data.filter(['Open'])
amzn_open = amzn_data.filter(['Open'])
pfe_open = pfe_data.filter(['Open'])
googl_open = googl_data.filter(['Open'])
lrlcy_open = lrlcy_data.filter(['Open'])
dell_open = dell_data.filter(['Open'])
unh_open = unh_data.filter(['Open'])

# %%
#SH
#Relabeling Columns to Make Data More Readable 
msft_open = msft_open.rename(columns = {"Open": "MSFT"}) 
aapl_open = aapl_open.rename(columns = {"Open": "AAPL"}) 
tsla_open = tsla_open.rename(columns = {"Open": "TSLA"}) 
sony_open = sony_open.rename(columns = {"Open": "SONY"}) 
mcd_open = mcd_open.rename(columns = {"Open": "MCD"}) 
fb_open = fb_open.rename(columns = {"Open": "FB"}) 
jpm_open = jpm_open.rename(columns = {"Open": "JPM"}) 
dis_open = dis_open.rename(columns = {"Open": "DIS"}) 
cost_open = cost_open.rename(columns = {"Open": "COST"}) 
cvs_open = cvs_open.rename(columns = {"Open": "CVS"}) 
nflx_open = nflx_open.rename(columns = {"Open": "NFLX"}) 
sbux_open = sbux_open.rename(columns = {"Open": "SBUX"}) 
uber_open = uber_open.rename(columns = {"Open": "UBER"}) 
nke_open = nke_open.rename(columns = {"Open": "NKE"}) 
amzn_open = amzn_open.rename(columns = {"Open": "AMZN"}) 
pfe_open = pfe_open.rename(columns = {"Open": "PFE"}) 
googl_open = googl_open.rename(columns = {"Open": "GOOGL"}) 
lrlcy_open = lrlcy_open.rename(columns = {"Open": "LRLCY"}) 
dell_open = dell_open.rename(columns = {"Open": "DELL"}) 
unh_open = unh_open.rename(columns = {"Open": "UNH"})

# %%
#SH
#Creating the DataFrame Table of the Sample Stock Data 

price_df = pd.concat([msft_open,
aapl_open,
tsla_open,
sony_open,
mcd_open,
fb_open,
jpm_open,
dis_open,
cost_open,
cvs_open,
nflx_open,
sbux_open,
uber_open,
nke_open,
amzn_open,
# 2021-07-26  40.887518  2666.570068  90.989998  49.021793  414.021658
# ...               ...          ...        ...        ...         ...
# 2021-12-02  53.820000  2825.000000  90.989998  55.500000  441.709342
# 2021-12-03  53.709999  2873.620117  90.919998  57.500000  447.769989
# 2021-12-06  53.779999  2860.810059  91.970001  58.750000  452.149994
# 2021-12-07  51.250000  2911.929932  93.989998  59.250000  462.750000
# 2021-12-08  52.750000  2951.929932  95.879997  59.000000  466.089996
#
# [100 rows x 20 columns]

# %%
#SH
#Function to Pull Open Price from a Stock Ticker Directly Through API 

def ticker_price_open():
    ticker_name = input("Enter Ticker Name")
    ticker_symbol = yf.Ticker(ticker_name)
    ticker_data = ticker_symbol.history(period="max")
    ticker_open = ticker_data.filter(['Open'])
    ticker_open = ticker_open.rename(columns = {"Open": ticker_name}) 
    print(ticker_open)

# %%
#SH
ticker_price_open()
# Out:
# Enter Ticker Name TSLA
#                    TSLA
# Date
# 2010-06-29     3.800000
# 2010-06-30     5.158000
# 2010-07-01     5.000000
# 2010-07-02     4.600000
# 2010-07-06     4.000000
# ...                 ...
# 2021-12-02  1099.060059
# 2021-12-03  1084.790039
# 2021-12-06  1001.510010
# 2021-12-07  1044.199951
# 2021-12-08  1052.709961
#
# [2883 rows x 1 columns]

# %% [markdown]
# # COMBINING STOCK API DATA WITH USER DATA

# %%
#SH
#Sample of User Data Over Past 100 Days
user_test = pd.read_csv('TEST_USER_DATA.csv')
user_test
# Out:
#     AAPL Net Stocks Bought/Sold  TSLA Net Stocks Bought/Sold  \
# 0                             7                           -4
# 1                            -8                           -9
# 2                            16                          -13
# 3                            -6                           11
# 4                            16                          -17
# ..                          ...                          ...
# 95                           -6                          -19
# 96                           12                            7
# 97                           20                            0
# 98                           -3                          -12
# 99                           19                          -13
#
#     SONY Net Stocks Bought/Sold  MCD Net Stocks Bought/Sold  \
# 0                             2                          -5
# 1                            16                          -4
# 2                           -15                          -2
# 3                            -7                         -11
# 4                            -2                          15
# ..                          ...                         ...
# 95                            2                         -20
# 96                           -2                          14
# 97                          -12                          19
# 98                            1                          -1
# 99                           -2                           2
#
#     FB Net Stocks Bought/Sold  JPM Net Stocks Bought/Sold  \
# 0                          -4                         -14
# 1                         -16                         -10
# 2                           4                           1
# 3                         -17                           0
# 4                          19                           9
# ..                        ...                         ...
# 95                         -7                           6
# 96                         13                         -12
# 97                         16                         -11
# 98                         18                          -7
# 99                         -4                           8
#
#     DIS Net Stocks Bought/Sold  COST Net Stocks Bought/Sold  \
# 0                          -18                            2
# 1                          -19                          -16
# 2                          -20                           -6
# 3                          -14                            3
# 4                            1                          -16
# ..                         ...                          ...
# 95                          17                          -17
# 96                          12                           18
# 97                           1                          -10
# 98                          18                          -15
# 99                          13                           20
#
#     CVS Net Stocks Bought/Sold  NFLX Net Stocks Bought/Sold  \
# 0                           -9                           -1
# 1                           17                           10
# 2                          -15                           14
# 3                           -6                            8
# 4                           18                           16
# ..                         ...                          ...
# 95                           9                            7
# 96                           3                           -4
# 97                          10                           -9
# 98                          18                           17
# 99                           2                           20
#
#     SBUX Net Stocks Bought/Sold  UBER Net Stocks Bought/Sold  \
# 0                            -9                           -7
# 1                            10                            2
# 2                             1                          -18
# 3                            19                          -19
# 4                            -6                          -17
# ..                          ...                          ...
# 95                          -19                           10
# 96                          -10                           19
# 97                          -19                          -17
# 98                           19                           15
# 99                          -20                            1
#
#     NKE Net Stocks Bought/Sold  AMZN Net Stocks Bought/Sold  \
# 0                          -14                            0
# 1                          -19                           -8
# 2                           18                            4
# 3                           -8                          -15
# 4                            9                           -1
# ..                         ...                          ...
# 95                           5                           -1
# 96                          10                           17
# 97                          10                           19
# 98                          -9                           15
# 99                         -18                            9
#
#     PFE Net Stocks Bought/Sold  GOOGL Net Stocks Bought/Sold  \
# 0                           -3                            15
# 1                          -14                            20
# 2                           11                           -18
# 3                           -5                           -15
# 4                          -11                            10
# ..                         ...                           ...
# 95                           1                             9
# 96                         -20                            -5
# 97                          15                            18
# 98                          13                           -12
# 99                          12                            -4
#
#     LRLCY Net Stocks Bought/Sold  DELL Net Stocks Bought/Sold  \
# 0                             17                           -9
# 1                            -11                          -15
# 2                            -19                          -14
# 3                             15                           -5
# 4                            -18                          -20
# ..                           ...                          ...
# 95                           -13                           -8
# 96                           -14                           19
# 97                             5                           18
# 98                            18                            0
# 99                            -6                            9
#
#     UNH Net Stocks Bought/Sold  MSFT Net Stocks Bought/Sold
# 0                          -13                           14
# 1                           -9                           12
# 2                           16                          -11
# 3                          -11                           17
# 4                            9                           -8
# ..                         ...                          ...
# 95                           6                            1
# 96                          19                           11
# 97                          17                           -8
# 98                          13                           -9
# 99                         -20                            6
#
# [100 rows x 20 columns]

# %%
#SH
#Converting to Array
user_test_column_names = np.asarray(list(user_test))

# %%
#SH
#Combining the Two DataFrames
price_df_last_100[user_test_column_names] = user_test[user_test_column_names].values

# %%
#Combining the Two DataFrames
price_df_last_100[user_test_column_names] = user_test[user_test_column_names].values
# Out:
# C:\Users\Sandelemental\anaconda3\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
#SH
#DUE TO WAY DATA IS SETUP. NEED TO INVERSE VALUE AS BUYING RESULTS IN NEGATIVE DUE TO REQUIRING TO SPEND MONEY TO BUY STOCKS AND VICE VERSA
price_df_last_100["AAPL TOTAL NET $ EARNED"] = price_df_last_100["AAPL"] * price_df_last_100["AAPL Net Stocks Bought/Sold"] *-1
price_df_last_100["TSLA TOTAL NET $ EARNED"] = price_df_last_100["TSLA"] * price_df_last_100["TSLA Net Stocks Bought/Sold"] *-1
price_df_last_100["SONY TOTAL NET $ EARNED"] = price_df_last_100["SONY"] * price_df_last_100["SONY Net Stocks Bought/Sold"] *-1
price_df_last_100["MCD TOTAL NET $ EARNED"] = price_df_last_100["MCD"] * price_df_last_100["MCD Net Stocks Bought/Sold"] *-1
price_df_last_100["FB TOTAL NET $ EARNED"] = price_df_last_100["FB"] * price_df_last_100["FB Net Stocks Bought/Sold"] *-1
price_df_last_100["JPM TOTAL NET $ EARNED"] = price_df_last_100["JPM"] * price_df_last_100["JPM Net Stocks Bought/Sold"] *-1
price_df_last_100["DIS TOTAL NET $ EARNED"] = price_df_last_100["DIS"] * price_df_last_100["DIS Net Stocks Bought/Sold"] *-1
price_df_last_100["COST TOTAL NET $ EARNED"] = price_df_last_100["COST"] * price_df_last_100["COST Net Stocks Bought/Sold"] *-1
price_df_last_100["CVS TOTAL NET $ EARNED"] = price_df_last_100["CVS"] * price_df_last_100["CVS Net Stocks Bought/Sold"] *-1
price_df_last_100["NFLX TOTAL NET $ EARNED"] = price_df_last_100["NFLX"] * price_df_last_100["NFLX Net Stocks Bought/Sold"] *-1
price_df_last_100["SBUX TOTAL NET $ EARNED"] = price_df_last_100["SBUX"] * price_df_last_100["SBUX Net Stocks Bought/Sold"] *-1
price_df_last_100["UBER TOTAL NET $ EARNED"] = price_df_last_100["UBER"] * price_df_last_100["UBER Net Stocks Bought/Sold"] *-1
price_df_last_100["NKE TOTAL NET $ EARNED"] = price_df_last_100["NKE"] * price_df_last_100["NKE Net Stocks Bought/Sold"] *-1
price_df_last_100["AMZN TOTAL NET $ EARNED"] = price_df_last_100["AMZN"] * price_df_last_100["AMZN Net Stocks Bought/Sold"] *-1
price_df_last_100["PFE TOTAL NET $ EARNED"] = price_df_last_100["PFE"] * price_df_last_100["PFE Net Stocks Bought/Sold"] *-1
price_df_last_100["GOOGL TOTAL NET $ EARNED"] = price_df_last_100["GOOGL"] * price_df_last_100["GOOGL Net Stocks Bought/Sold"] *-1
price_df_last_100["LRLCY TOTAL NET $ EARNED"] = price_df_last_100["LRLCY"] * price_df_last_100["LRLCY Net Stocks Bought/Sold"] *-1
price_df_last_100["DELL TOTAL NET $ EARNED"] = price_df_last_100["DELL"] * price_df_last_100["DELL Net Stocks Bought/Sold"] *-1
price_df_last_100["UNH TOTAL NET $ EARNED"] = price_df_last_100["UNH"] * price_df_last_100["UNH Net Stocks Bought/Sold"] *-1
price_df_last_100["MSFT TOTAL NET $ EARNED"] = price_df_last_100["MSFT"] * price_df_last_100["MSFT Net Stocks Bought/Sold"] *-1
# Out:
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["AAPL TOTAL NET $ EARNED"] = price_df_last_100["AAPL"] * price_df_last_100["AAPL Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["TSLA TOTAL NET $ EARNED"] = price_df_last_100["TSLA"] * price_df_last_100["TSLA Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["SONY TOTAL NET $ EARNED"] = price_df_last_100["SONY"] * price_df_last_100["SONY Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["MCD TOTAL NET $ EARNED"] = price_df_last_100["MCD"] * price_df_last_100["MCD Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["FB TOTAL NET $ EARNED"] = price_df_last_100["FB"] * price_df_last_100["FB Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["JPM TOTAL NET $ EARNED"] = price_df_last_100["JPM"] * price_df_last_100["JPM Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["DIS TOTAL NET $ EARNED"] = price_df_last_100["DIS"] * price_df_last_100["DIS Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["COST TOTAL NET $ EARNED"] = price_df_last_100["COST"] * price_df_last_100["COST Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["CVS TOTAL NET $ EARNED"] = price_df_last_100["CVS"] * price_df_last_100["CVS Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["NFLX TOTAL NET $ EARNED"] = price_df_last_100["NFLX"] * price_df_last_100["NFLX Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["SBUX TOTAL NET $ EARNED"] = price_df_last_100["SBUX"] * price_df_last_100["SBUX Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["UBER TOTAL NET $ EARNED"] = price_df_last_100["UBER"] * price_df_last_100["UBER Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["NKE TOTAL NET $ EARNED"] = price_df_last_100["NKE"] * price_df_last_100["NKE Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["AMZN TOTAL NET $ EARNED"] = price_df_last_100["AMZN"] * price_df_last_100["AMZN Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["PFE TOTAL NET $ EARNED"] = price_df_last_100["PFE"] * price_df_last_100["PFE Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["GOOGL TOTAL NET $ EARNED"] = price_df_last_100["GOOGL"] * price_df_last_100["GOOGL Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["LRLCY TOTAL NET $ EARNED"] = price_df_last_100["LRLCY"] * price_df_last_100["LRLCY Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["DELL TOTAL NET $ EARNED"] = price_df_last_100["DELL"] * price_df_last_100["DELL Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["UNH TOTAL NET $ EARNED"] = price_df_last_100["UNH"] * price_df_last_100["UNH Net Stocks Bought/Sold"] *-1
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/2244441095.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df_last_100["MSFT TOTAL NET $ EARNED"] = price_df_last_100["MSFT"] * price_df_last_100["MSFT Net Stocks Bought/Sold"] *-1

# %%
#SH
#To View Just One Stock's Performance
print(price_df_last_100.filter(regex='AAPL')) 
print("AAPL TOTAL NET $ EARNED OVER PAST 100 DAYS", price_df_last_100["AAPL TOTAL NET $ EARNED"].sum())
# Out:
#                   AAPL  AAPL Net Stocks Bought/Sold  AAPL TOTAL NET $ EARNED
# Date
# 2021-07-20  143.036640                            7             -1001.256482
# 2021-07-21  145.100507                           -8              1160.804060
# 2021-07-22  145.509298                           16             -2328.148763
# 2021-07-23  147.114553                           -6               882.687318
# 2021-07-26  147.832432                           16             -2365.318910
# ...                ...                          ...                      ...
# 2021-12-02  158.740005                           -6               952.440033
# 2021-12-03  164.020004                           12             -1968.240051
# 2021-12-06  164.289993                           20             -3285.799866
# 2021-12-07  169.080002                           -3               507.240005
# 2021-12-08  172.125000                           19             -3270.375000
#
# [100 rows x 3 columns]
# AAPL TOTAL NET $ EARNED OVER PAST 100 DAYS -26459.038147667423

# %%
#SH
#To Sort Filtered Dataframe
price_df_last_100 = price_df_last_100.reindex(sorted(price_df_last_100.columns), axis=1)
price_df_last_100
# Out:
#                   AAPL  AAPL Net Stocks Bought/Sold  AAPL TOTAL NET $ EARNED  \
# Date
# 2021-07-20  143.036640                            7             -1001.256482
# 2021-07-21  145.100507                           -8              1160.804060
# 2021-07-22  145.509298                           16             -2328.148763
# 2021-07-23  147.114553                           -6               882.687318
# 2021-07-26  147.832432                           16             -2365.318910
# ...                ...                          ...                      ...
# 2021-12-02  158.740005                           -6               952.440033
# 2021-12-03  164.020004                           12             -1968.240051
# 2021-12-06  164.289993                           20             -3285.799866
# 2021-12-07  169.080002                           -3               507.240005
# 2021-12-08  172.125000                           19             -3270.375000
#
#                    AMZN  AMZN Net Stocks Bought/Sold  AMZN TOTAL NET $ EARNED  \
# Date
# 2021-07-20  3567.320068                            0                -0.000000
# 2021-07-21  3576.379883                           -8             28611.039062
# 2021-07-22  3587.229980                            4            -14348.919922
# 2021-07-23  3640.000000                          -15             54600.000000
# 2021-07-26  3673.169922                           -1              3673.169922
# ...                                ...                     ...
# 2021-12-02                           6            -2650.256054
# 2021-12-03                          19            -8507.629791
# 2021-12-06                          17            -7686.549896
# 2021-12-07                          13            -6015.750000
# 2021-12-08                         -20             9321.799927
#
# [100 rows x 60 columns]

# %%
#SH
# To View Net Performance of All Stocks Over Each Day

price_df_last_100["TOTAL NET $ EARNED"] = price_df_last_100.sum(axis=1) #To Add Column That Sums Up Total Net $ Earned That Day

price_df_last_100.filter(regex="TOTAL NET")
# Out:
#             AAPL TOTAL NET $ EARNED  AMZN TOTAL NET $ EARNED  \
# Date
# 2021-07-20             -1001.256482                -0.000000
# 2021-07-21              1160.804060             28611.039062
# 2021-07-22             -2328.148763            -14348.919922
# 2021-07-23               882.687318             54600.000000
# 2021-07-26             -2365.318910              3673.169922
# ...                             ...                      ...
# 2021-12-02               952.440033              3460.000000
# 2021-12-03             -1968.240051            -58735.000000
# 2021-12-06             -3285.799866            -64467.000000
# 2021-12-07               507.240005            -52380.000000
# 2021-12-08             -3270.375000            -31707.090088
#
#             COST TOTAL NET $ EARNED  CVS TOTAL NET $ EARNED  \
# Date
# 2021-07-20              -825.115886              719.447176
# 2021-07-21              6650.513826            -1384.995835
# 2021-07-22              2487.305928             1233.482714
# 2021-07-23             -1250.499084              495.123067
# 2021-07-26              6750.803515            -1493.064510
# ...                             ...                     ...
# 2021-12-02              8814.670166             -802.169975
# 2021-12-03             -9539.819824             -271.919998
# 2021-12-06              5322.500000             -916.299973
# 2021-12-07              8073.750000            -1674.180038
# 2021-12-08            -10924.200439             -186.660004
#
#             DELL TOTAL NET $ EARNED  DIS TOTAL NET $ EARNED  \
# Date
# 2021-07-20               426.097321             3126.599945
# 2021-07-21               727.572212             3353.500000
# 2021-07-22               684.602104             3533.999939
# 2021-07-23               243.284340             2459.240051
# 2021-07-26               980.435867             -175.619995
# ...                             ...                     ...
# 2021-12-02               444.000000            -2428.279938
# 2021-12-03             -1092.500000            -1773.719971
# 2021-12-06             -1057.500000             -147.279999
# 2021-12-07                -0.000000            -2733.119934
# 2021-12-08              -531.000000            -1961.830048
#
#             FB TOTAL NET $ EARNED  GOOGL TOTAL NET $ EARNED  \
# Date
# 2021-07-20            1355.199951             -37658.250732
# 2021-07-21            5464.000000             -50453.398438
# 2021-07-22           -1386.719971              46023.837891
# 2021-07-23            6135.470062              39129.151611
# 2021-07-26           -7022.019745             -26665.700684
# ...                           ...                       ...
# 2021-12-02            2179.799957             -25425.000000
# 2021-12-03           -4078.490143              14368.100586
# 2021-12-06           -4930.080078             -51494.581055
# 2021-12-07           -5788.260132              34943.159180
# 2021-12-08            1300.000000              11807.719727
#
#             JPM TOTAL NET $ EARNED  LRLCY TOTAL NET $ EARNED  ...  \
# Date                                                          ...
# 2021-07-20             2038.993364              -1522.350052  ...
# 2021-07-21             1511.392512                982.190010  ...
# 2021-07-22             -151.964287               1689.290070  ...
# 2021-07-23               -0.000000              -1352.400055  ...
# 2021-07-26            -1343.613526               1637.819962  ...
# ...                            ...                       ...  ...
# 2021-12-02             -958.980011               1182.869972  ...
# %% [markdown]
# # BUILDING SUMMARIES BASED ON DATA

# %%
#SH
#Building Summary for Stocks Remaining

total_stocks_remaining_summary = price_df_last_100.filter(regex="Stock").sum()
stocks_remaining_df = total_stocks_remaining_summary.where(total_stocks_remaining_summary > 0).to_frame() #Filtering Out Negative Values

stocks_remaining_df = stocks_remaining_df.rename(columns = {0: "Stocks Remaining"})

# %%
#SH
#Sorting the Data By Column
price_df_sorted = price_df.reindex(sorted(price_df.columns), axis=1)

#Changing Row to Column
current_day_price_column = price_df_sorted[-1:].transpose()

#NEED THIS TO RELABEL WITH CONSTANTLY CHANGING COLUMN LABEL DUE TO API LIVE PULLING DATA
current_day_price_column.rename(columns = {list(current_day_price_column)[0]: 'Current Day Price'}, inplace = True)

# %%
#SH
stocks_remaining_df["Current Day Price"] = current_day_price_column["Current Day Price"].values
stocks_remaining_df["Value of Stocks Owned"] = stocks_remaining_df["Stocks Remaining"] * stocks_remaining_df["Current Day Price"]

#Removing All NaNs
stocks_remaining_dropna = stocks_remaining_df.dropna()

total_stocks_remaining_summary = stocks_remaining_dropna["Value of Stocks Owned"].sum()
print("Total Value of Stocks Owned:",total_stocks_remaining_summary)
stocks_remaining_dropna
# Out:
# Total Value of Stocks Owned: 1379904.3685035706
#                              Stocks Remaining  Current Day Price  \
# AAPL Net Stocks Bought/Sold             167.0         172.125000
# AMZN Net Stocks Bought/Sold             295.0        3523.010010
# CVS Net Stocks Bought/Sold              294.0          93.330002
# DIS Net Stocks Bought/Sold              183.0         150.910004
# JPM Net Stocks Bought/Sold               17.0         162.660004
# MCD Net Stocks Bought/Sold               40.0         260.000000
# MSFT Net Stocks Bought/Sold             385.0         335.309998
# NFLX Net Stocks Bought/Sold             149.0         630.000000
# SONY Net Stocks Bought/Sold             152.0         125.260002
# UBER Net Stocks Bought/Sold              43.0          38.299999
#
#                              Value of Stocks Owned
# AAPL Net Stocks Bought/Sold           2.874488e+04
# AMZN Net Stocks Bought/Sold           1.039288e+06
# CVS Net Stocks Bought/Sold            2.743902e+04
# DIS Net Stocks Bought/Sold            2.761653e+04
# JPM Net Stocks Bought/Sold            2.765220e+03
# MCD Net Stocks Bought/Sold            1.040000e+04
# MSFT Net Stocks Bought/Sold           1.290943e+05
# NFLX Net Stocks Bought/Sold           9.387000e+04
# SONY Net Stocks Bought/Sold           1.903952e+04
# UBER Net Stocks Bought/Sold           1.646900e+03

# %%
#SH
total_earned_column_names = np.asarray(list(price_df_last_100.filter(regex="TOTAL NET")))

total_earned_summary = price_df_last_100[total_earned_column_names].sum()

print("Total Summary of User's Stock Gains/Losses:")

print(total_earned_summary)

print("Total Gains and Losses:", total_earned_summary.sum())
# Out:
# Total Summary of User's Stock Gains/Losses:
# AAPL TOTAL NET $ EARNED     -26459.038148
# AMZN TOTAL NET $ EARNED    -974984.654297
# COST TOTAL NET $ EARNED      14094.444664
# CVS TOTAL NET $ EARNED      -26351.416592
# DELL TOTAL NET $ EARNED        936.848572
# DIS TOTAL NET $ EARNED      -30956.209549
# FB TOTAL NET $ EARNED        88954.700226
# GOOGL TOTAL NET $ EARNED    146909.672119
# JPM TOTAL NET $ EARNED       -1877.072724
# LRLCY TOTAL NET $ EARNED      9775.809967
# MCD TOTAL NET $ EARNED       -9050.351238
# MSFT TOTAL NET $ EARNED    -118033.543195
# NFLX TOTAL NET $ EARNED     -75361.148621
# NKE TOTAL NET $ EARNED       24523.184826
# PFE TOTAL NET $ EARNED        1757.100079
# SBUX TOTAL NET $ EARNED      26595.655020
# SONY TOTAL NET $ EARNED     -16386.529861
# TSLA TOTAL NET $ EARNED     -15846.219299
# UBER TOTAL NET $ EARNED      -2093.904922
# UNH TOTAL NET $ EARNED       36609.799689
# dtype: float64
# Total Gains and Losses: -947242.873284665

# %%
#SH
#Final Net Portfolio Value

print("Final Net Portfolio Value:", total_stocks_remaining_summary + total_earned_summary.sum())
# Out:
# Final Net Portfolio Value: 432661.4952189055

# %% [markdown]
# # CONNIE'S CODE

# %%
#Install Yahoo! Finance market data
# !pip install yfinance
import yfinance as yf #Allows us to Use Yahoo Finance API 
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: yfinance in c:\users\sandelemental\anaconda3\lib\site-packages (0.1.67)
# Requirement already satisfied: pandas>=0.24 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (1.3.3)
# Requirement already satisfied: requests>=2.20 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\sandelemental\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sandelemental\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (3.2)

# %%
#Pull 10 largest exchange-traded fund (ETF)s from Yahoo! Finance

#1. SPDR S&P 500 (SPY) - This fund is the oldest ETF on the market. SPY trackes the S&P 500 index, incluing about 500 of the largest U.S. stocks 
#2. Vanguard Total Stock Market ETF (VTI) -Vanguard has some of the best ETFs with high assets on the market. 
#3. Vanguard S&P 500 ETF (VOO) - Cheapest Vanguard ETF 
#4. Vanguard FTSE Emerging Markets ETF (VWO) - FTSE Emerging Markets All Cap China A Inclusion Index, incluing large, mid, and small cap stocks
#5. Vanguard FTSE Developed Markets ETF (VEA) - VEA tracks the FTSE Developed All Cap ex-US Index, representing approximately 3,700 common stocks of large-, mid-, and small-cap companies located in Canada
#6. Invesco QQQ Trust Series 1 (QQQ) - This ETF includes the 100 largest non-financial companies listed on the nasdaq including AAPL, MSFT, AMZN, TSLA, GOOG, FB, etc.- https://www.invesco.com/qqq-etf/en/home.html
#7. iShares Core S&P 500 (IVV) - By BlackRock, the largest ETF company in the world*
#8. iShares Core MSCI EAFE (IEFA) - IEFA is another ETF to make our list that tracks the MSCI EAFE, which includes stock of companies in non-U.S. countries in Europe, Japan, and Australia
#9. iShares MSCI EAFE (EFA) - EFA is the biggest ETF that invests in international stocks.
#10. iShares Core US Aggregate Bond (AGG) - The largest bond ETF in the world, as measured by assets under management, AGG tracks the Barclays Aggregate U.S.


#yf.Ticker().info prints out a JSON
spy = yf.Ticker('SPY').info
vti = yf.Ticker('VTI').info
voo = yf.Ticker('VOO').info
vwo = yf.Ticker('VWO').info
vea = yf.Ticker('VEA').info
qqq = yf.Ticker('QQQ').info
ivv = yf.Ticker('IVV').info
iefa = yf.Ticker('IEFA').info
efa = yf.Ticker('EFA').info
agg = yf.Ticker('AGG').info

# %%
# Use json.dump to store the above 10 largest ETFs into etf.jSon file

# The json file where the output must be stored
etf = [spy, vti, voo, vwo, vea, qqq, ivv, iefa, efa, agg]
out_file = open("etf.json", "w") 
json.dump(etf, out_file, indent = 6)
out_file.close()

# %%
#read etf.json file
with open('etf.json') as file:
    file_data = json.load(file)
file_data
# Out:
# [{'exchange': 'PCX',
#   'shortName': 'SPDR S&P 500',
#   'longName': 'SPDR S&P 500 ETF Trust',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-18000000',
#   'quoteType': 'ETF',
#   'symbol': 'SPY',
#   'messageBoardId': 'finmb_6160262',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': None,
#   'beta3Year': 1,
#   'profitMargins': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'fundInceptionDate': 727660800,
#   'annualReportExpenseRatio': None,
#   'totalAssets': 374031319040,
#   'bookValue': None,
#   'fundFamily': 'SPDR State Street Global Advisors',
#   'lastFiscalYearEnd': None,
#   'netIncomeToCommon': None,
#   'trailingEps': None,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': None,
#   'nextFiscalYearEnd': None,
#   'yield': 0.012999999,
#   'mostRecentQuarter': None,
#   'enterpriseValue': None,
#   'priceHint': 2,
#   'threeYearAverageReturn': 0.2337,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': 'Exchange Traded Fund',
#   'lastDividendDate': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'maxAge': 1,
#   'lastCapGain': None,
#   'category': 'Large Blend',
#   'fiveYearAverageReturn': 0.184,
#   'phone': '866-732-8673',
#   'longBusinessSummary': 'The investment seeks to provide investment results that, before expenses, correspond generally to the price and yield performance of the S&P 500Â® Index.\n The Trust seeks to achieve its investment objective by holding a portfolio of the common stocks that are included in the index (the â\x80\x9cPortfolioâ\x80\x9d), with the weight of each stock in the Portfolio substantially corresponding to the weight of such stock in the index.',
#   'companyOfficers': [],
#   'previousClose': 468.28,
#   'regularMarketOpen': 468.7,
#   'twoHundredDayAverage': 430.33456,
#   'trailingAnnualDividendYield': 0.011879645,
#   'payoutRatio': None,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 470,
#   'navPrice': 467.48,
#   'averageDailyVolume10Day': 107306270,
#   'regularMarketPreviousClose': 468.28,
#   'fiftyDayAverage': 454.116,
#   'trailingAnnualDividendRate': 5.563,
#   'open': 468.7,
#   'toCurrency': None,
#   'averageVolume10days': 107306270,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': None,
#   'exDividendDate': None,
#   'beta': None,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 466.83,
#   'currency': 'USD',
#   'trailingPE': 3.258112,
#   'regularMarketVolume': 71233533,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': None,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 78303976,
#   'dayLow': 466.83,
#   'ask': 469.58,
#   'askSize': 1000,
#   'volume': 71233533,
#   'fiftyTwoWeekHigh': 473.54,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 362.03,
#   'bid': 469.64,
#   'tradeable': False,
#   'dividendYield': None,
#   'bidSize': 800,
#   'dayHigh': 470,
#   'preferredPosition': None,
#   'bondPosition': 0,
#   'convertiblePosition': None,
#   'sectorWeightings': [{'realestate': 0.0257},
#    {'consumer_cyclical': 0.12},
#    {'basic_materials': 0.0227},
#    {'consumer_defensive': 0.063200004},
#    {'technology': 0.24219999},
#    {'communication_services': 0.1114},
#    {'financial_services': 0.1423},
#    {'utilities': 0.024500001},
#    {'industrials': 0.088599995},
#    {'energy': 0.0286},
#    {'healthcare': 0.1309}],
#   'holdings': [{'symbol': 'AAPL',
#     'holdingName': 'Apple Inc',
#     'holdingPercent': 0.059},
#    {'symbol': 'MSFT',
#     'holdingName': 'Microsoft Corp',
#     'holdingPercent': 0.055999998},
#    {'symbol': 'AMZN',
#     'holdingName': 'Amazon.com Inc',
#     'holdingPercent': 0.0405},
#    {'symbol': 'FB', 'holdingName': 'Facebook Inc A', 'holdingPercent': 0.0229},
#    {'symbol': 'GOOGL',
#     'holdingName': 'Alphabet Inc A',
#     'holdingPercent': 0.0202},
#    {'symbol': 'GOOG',
#     'holdingName': 'Alphabet Inc Class C',
#     'holdingPercent': 0.0196},
#    {'symbol': 'BRK.B',
#     'holdingName': 'Berkshire Hathaway Inc Class B',
#     'holdingPercent': 0.0145000005},
#    {'symbol': 'TSLA',
#     'holdingName': 'Tesla Inc',
#     'holdingPercent': 0.014400001},
#    {'symbol': 'NVDA', 'holdingName': 'NVIDIA Corp', 'holdingPercent': 0.0137},
#    {'symbol': 'JPM',
#     'holdingName': 'JPMorgan Chase & Co',
#     'holdingPercent': 0.0128999995}],
#   'bondHoldings': {'maturity': None,
#    'duration': None,
#    'creditQuality': None,
#    'maturityCat': None,
#    'durationCat': None,
#    'creditQualityCat': None},
#   'bondRatings': [{'bb': 0},
#    {'aa': 0},
#    {'aaa': 0},
#    {'a': 0},
#    {'other': 0},
#    {'b': 0},
#    {'bbb': 0},
#    {'below_b': 0},
#    {'us_government': 0}],
#   'equityHoldings': {'priceToCashflow': 17.56,
#    'priceToSales': 2.96,
#    'priceToBookCat': None,
#    'priceToEarningsCat': None,
#    'medianMarketCapCat': None,
#    'threeYearEarningsGrowthCat': None,
#    'threeYearEarningsGrowth': None,
#    'medianMarketCap': None,
#    'priceToEarnings': 26.45,
#    'priceToBook': 4.42,
#    'priceToSalesCat': None,
#    'priceToCashflowCat': None},
#   'otherPosition': None,
#   'cashPosition': None,
#   'stockPosition': 0.9971,
#   'regularMarketPrice': 469.52,
#   'preMarketPrice': 468.68,
#   'logo_url': ''},
#  {'exchange': 'PCX',
#   'shortName': 'Vanguard Total Stock Market ETF',
#   'longName': 'Vanguard Index Funds - Vanguard Total Stock Market ETF',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-18000000',
#   'quoteType': 'ETF',
#   'symbol': 'VTI',
#   'messageBoardId': 'finmb_6184536',
#   'market': 'us_market',
#   'err': {'elapsedTime': 22,
#    'headers': {'server': 'envoy',
#     'x-envoy-upstream-service-time': '6',
#     'via': 'https/1.1 media-router-api7003.prod.media.bf1.yahoo.com (ApacheTrafficServer [cMsSf ])',
#     'content-type': 'application/json;charset=utf-8',
#     'x-request-id': 'c7fb7502-7f99-4e85-a8c3-9cbec03309f5',
#     'date': 'Wed, 08 Dec 2021 21:47:06 GMT',
#     'cache-control': 'max-age=0, private',
#     'vary': 'Origin',
#     'expires': '-1',
#     'y-rid': 'bjj1qr5gr29uq',
#     'content-length': '216',
#     'x-yahoo-request-id': 'bjj1qr5gr29uq',
#     'age': '0'},
#    'requestUri': 'http://iquery.finance.yahoo.com:4080/v10/finance/quoteSummary/VTI?formatted=true&crumb=xdRI80P1Lie&lang=en-US&region=US&modules=defaultKeyStatistics%2CassetProfile%2CtopHoldings%2CfundPerformance%2CfundProfile%2CesgScores&ssl=true',
#    'responseText': '{"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for any of the summaryTypes=defaultKeyStatistics,assetProfile,topHoldings,fundPerformance,fundProfile,esgScores"}}}',
#    'responseXML': None,
#    'status': 404,
#    'statusCode': 404,
#    'statusText': 'Not Found'},
#   'quoteSourceName': 'Nasdaq Real Time Price',
#   'regularMarketOpen': 239.57,
#   'averageDailyVolume3Month': 3598201,
#   'regularMarketTime': 1638997200,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 240.3794,
#   'averageDailyVolume10Day': 4761800,
#   'regularMarketChange': 1.03,
#   'currencySymbol': '$',
#   'regularMarketPreviousClose': 239.17,
#   'postMarketTime': 1639000020,
#   'preMarketPrice': 239.61,
#   'preMarketTime': 1638973795,
#   'exchangeDataDelayedBy': 0,
#   'toCurrency': None,
#   'postMarketChange': -0.009994507,
#   'postMarketPrice': 240.19,
#   'exchangeName': 'NYSEArca',
#   'preMarketChange': 0.440002,
#   'circulatingSupply': None,
#   'regularMarketDayLow': 238.64,
#   'priceHint': 2,
#   'currency': 'USD',
#   'regularMarketPrice': 240.2,
#   'regularMarketVolume': 3176880,
#   'lastMarket': None,
#   'regularMarketSource': 'FREE_REALTIME',
#   'openInterest': None,
#   'marketState': 'POST',
#   'underlyingSymbol': None,
#   'marketCap': 498107547648,
#   'preMarketChangePercent': 0.00183971,
#   'volumeAllCurrencies': None,
#   'postMarketSource': 'FREE_REALTIME',
#   'strikePrice': None,
#   'postMarketChangePercent': -4.1609102e-05,
#   'preMarketSource': 'FREE_REALTIME',
#   'maxAge': 1,
#   'fromCurrency': None,
#   'regularMarketChangePercent': 0.00430656,
#   'logo_url': ''},
#  {'exchange': 'PCX',
#   'shortName': 'Vanguard S&P 500 ETF',
#   'longName': 'Vanguard S&P 500 ETF',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-18000000',
#   'quoteType': 'ETF',
#   'symbol': 'VOO',
#   'messageBoardId': 'finmb_28117396',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': None,
#   'beta3Year': 1,
#   'profitMargins': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'fundInceptionDate': 1283817600,
#   'annualReportExpenseRatio': None,
#   'totalAssets': 753409982464,
#   'bookValue': None,
#   'fundFamily': 'Vanguard',
#   'lastFiscalYearEnd': None,
#   'netIncomeToCommon': None,
#   'trailingEps': None,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': None,
#   'nextFiscalYearEnd': None,
#   'yield': 0.0134000005,
#   'mostRecentQuarter': None,
#   'enterpriseValue': None,
#   'priceHint': 2,
#   'threeYearAverageReturn': 0.2337,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': 'Exchange Traded Fund',
#   'lastDividendDate': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'maxAge': 1,
#   'lastCapGain': None,
#   'category': 'Large Blend',
#   'fiveYearAverageReturn': 0.1844,
#   'phone': '866-499-8473',
#   'longBusinessSummary': 'The investment seeks to track the performance of the Standard & Poorâ\x80\x98s 500 Index that measures the investment return of large-capitalization stocks.\n The fund employs an indexing investment approach designed to track the performance of the Standard & Poor&#39;s 500 Index, a widely recognized benchmark of U.S. stock market performance that is dominated by the stocks of large U.S. companies. The advisor attempts to replicate the target index by investing all, or substantially all, of its assets in the stocks that make up the index, holding each stock in approximately the same proportion as its weighting in the index.',
#   'companyOfficers': [],
#   'previousClose': 430.49,
#   'regularMarketOpen': 430.95,
#   'twoHundredDayAverage': 395.75424,
#   'trailingAnnualDividendYield': 0.012318521,
#   'payoutRatio': None,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 432.125,
#   'navPrice': 429.82,
#   'averageDailyVolume10Day': 7501910,
#   'regularMarketPreviousClose': 430.49,
#   'fiftyDayAverage': 417.5362,
#   'trailingAnnualDividendRate': 5.303,
#   'open': 430.95,
#   'toCurrency': None,
#   'averageVolume10days': 7501910,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': None,
#   'exDividendDate': None,
#   'beta': None,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 429.24,
#   'currency': 'USD',
#   'trailingPE': 9.008765,
#   'regularMarketVolume': 4421732,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': None,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 5094692,
#   'dayLow': 429.24,
#   'ask': 431.69,
#   'askSize': 1000,
#   'volume': 4421732,
#   'fiftyTwoWeekHigh': 435.41,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 333.77,
#   'bid': 431.86,
#   'tradeable': False,
#   'dividendYield': None,
#   'bidSize': 1000,
#   'dayHigh': 432.125,
#   'preferredPosition': None,
#   'bondPosition': 0,
#   'convertiblePosition': None,
#   'sectorWeightings': [{'realestate': 0.025799999},
#    {'consumer_cyclical': 0.1201},
#    {'basic_materials': 0.0227},
#    {'consumer_defensive': 0.063200004},
#    {'technology': 0.24239999},
#    {'communication_services': 0.1114},
#    {'financial_services': 0.142},
#    {'utilities': 0.024300002},
#    {'industrials': 0.088599995},
#    {'energy': 0.028399998},
#    {'healthcare': 0.131}],
#   'holdings': [{'symbol': 'AAPL',
#     'holdingName': 'Apple Inc',
#     'holdingPercent': 0.0592},
#    {'symbol': 'MSFT',
#     'holdingName': 'Microsoft Corp',
#     'holdingPercent': 0.056199998},
#    {'symbol': 'AMZN',
#     'holdingName': 'Amazon.com Inc',
#     'holdingPercent': 0.040599998},
#    {'symbol': 'FB',
#     'holdingName': 'Facebook Inc Class A',
#     'holdingPercent': 0.0229},
#    {'symbol': 'GOOGL',
#     'holdingName': 'Alphabet Inc Class A',
#     'holdingPercent': 0.0202},
#    {'symbol': 'GOOG',
#     'holdingName': 'Alphabet Inc Class C',
#     'holdingPercent': 0.0197},
#    {'symbol': 'BRK.B',
#     'holdingName': 'Berkshire Hathaway Inc Class B',
#     'holdingPercent': 0.014400001},
#    {'symbol': 'TSLA',
#     'holdingName': 'Tesla Inc',
#     'holdingPercent': 0.014400001},
#    {'symbol': 'NVDA', 'holdingName': 'NVIDIA Corp', 'holdingPercent': 0.0137},
#    {'symbol': 'JPM',
#     'holdingName': 'JPMorgan Chase & Co',
#     'holdingPercent': 0.012999999}],
#   'bondHoldings': {'maturity': None,
#    'duration': None,
#    'creditQuality': None,
#    'maturityCat': None,
#    'durationCat': None,
#    'creditQualityCat': None},
#   'bondRatings': [{'bb': 0},
#    {'aa': 0},
#    {'aaa': 0},
#    {'a': 0},
#    {'other': 0},
#    {'b': 0},
#    {'bbb': 0},
#    {'below_b': 0},
#    {'us_government': 0}],
#   'equityHoldings': {'priceToCashflow': 17.57,
#    'priceToSales': 2.96,
#    'priceToBookCat': None,
#    'priceToEarningsCat': None,
#    'medianMarketCapCat': None,
#    'threeYearEarningsGrowthCat': None,
#    'threeYearEarningsGrowth': None,
#    'medianMarketCap': None,
#    'priceToEarnings': 26.46,
#    'priceToBook': 4.42,
#    'priceToSalesCat': None,
#    'priceToCashflowCat': None},
#   'otherPosition': None,
#   'cashPosition': None,
#   'stockPosition': 0.9996,
#   'regularMarketPrice': 431.7,
#   'preMarketPrice': 431,
#   'logo_url': ''},
#  {'exchange': 'PCX',
#   'shortName': 'Vanguard FTSE Emerging Markets ',
#   'longName': 'Vanguard FTSE Emerging Markets Index Fund ETF Shares',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-18000000',
#   'quoteType': 'ETF',
#   'symbol': 'VWO',
#   'messageBoardId': 'finmb_20936186',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': None,
#   'beta3Year': 0.96,
#   'profitMargins': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'fundInceptionDate': 1109894400,
#   'annualReportExpenseRatio': None,
#   'totalAssets': 117284003840,
#   'bookValue': None,
#   'fundFamily': 'Vanguard',
#   'lastFiscalYearEnd': None,
#   'netIncomeToCommon': None,
#   'trailingEps': None,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': None,
#   'nextFiscalYearEnd': None,
#   'yield': 0.0198,
#   'mostRecentQuarter': None,
#   'enterpriseValue': None,
#   'priceHint': 2,
#   'threeYearAverageReturn': 0.1241,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': 'Exchange Traded Fund',
#   'lastDividendDate': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'maxAge': 1,
#   'lastCapGain': None,
#   'category': 'Diversified Emerging Mkts',
#   'fiveYearAverageReturn': 0.098900005,
#   'phone': '800-662-7447',
#   'longBusinessSummary': 'The investment seeks to track the performance of a benchmark index that measures the investment return of stocks issued by companies located in emerging market countries.\n The fund employs an indexing investment approach designed to track the performance of the FTSE Emerging Markets All Cap China A Inclusion Index. It invests by sampling the index, meaning that it holds a broadly diversified collection of securities that, in the aggregate, approximates the index in terms of key characteristics.',
#   'companyOfficers': [],
#   'previousClose': 50.09,
#   'regularMarketOpen': 50.17,
#   'twoHundredDayAverage': 52.08625,
#   'trailingAnnualDividendYield': 0.019265322,
#   'payoutRatio': None,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 50.48,
#   'navPrice': 50.44,
#   'averageDailyVolume10Day': 16897450,
#   'regularMarketPreviousClose': 50.09,
#   'fiftyDayAverage': 50.7826,
#   'trailingAnnualDividendRate': 0.965,
#   'open': 50.17,
#   'toCurrency': None,
#   'averageVolume10days': 16897450,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': None,
#   'exDividendDate': None,
#   'beta': None,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 50.06,
#   'currency': 'USD',
#   'trailingPE': 3.2776115,
#   'regularMarketVolume': 11548270,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': None,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 11353614,
#   'dayLow': 50.06,
#   'ask': 50.38,
#   'askSize': 2900,
#   'volume': 11548270,
#   'fiftyTwoWeekHigh': 56.66,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 48.66,
#   'bid': 50.12,
#   'tradeable': False,
#   'dividendYield': None,
#   'bidSize': 43500,
#   'dayHigh': 50.48,
#   'preferredPosition': None,
#   'bondPosition': 0,
#   'convertiblePosition': None,
#   'sectorWeightings': [{'realestate': 0.0313},
#    {'consumer_cyclical': 0.161},
#    {'basic_materials': 0.08979999},
#    {'consumer_defensive': 0.0587},
#    {'technology': 0.1706},
#    {'communication_services': 0.1141},
#    {'financial_services': 0.1815},
#    {'utilities': 0.0255},
#    {'industrials': 0.059499998},
#    {'energy': 0.0548},
#    {'healthcare': 0.0533}],
#   'holdings': [{'symbol': '00700',
#     'holdingName': 'Tencent Holdings Ltd',
#     'holdingPercent': 0.0529},
#    {'symbol': '09988',
#     'holdingName': 'Alibaba Group Holding Ltd Ordinary Shares',
#     'holdingPercent': 0.0473},
#    {'symbol': '2330.TW',
#     'holdingName': 'Taiwan Semiconductor Manufacturing Co Ltd',
#     'holdingPercent': 0.0458},
#    {'symbol': '03690', 'holdingName': 'Meituan', 'holdingPercent': 0.0188},
#    {'symbol': 'TSM.TW',
#     'holdingName': 'Taiwan Semiconductor Manufacturing Co Ltd ADR',
#     'holdingPercent': 0.017},
#    {'symbol': 'RELIANCE.B',
#     'holdingName': 'Reliance Industries Ltd Shs Dematerialised',
#     'holdingPercent': 0.0106},
#    {'symbol': 'NPN.JO',
#     'holdingName': 'Naspers Ltd Class N',
#     'holdingPercent': 0.0101},
#    {'symbol': 'VALE3.SA', 'holdingName': 'Vale SA', 'holdingPercent': 0.0092},
#    {'symbol': 'INFY.BO',
#     'holdingName': 'Infosys Ltd',
#     'holdingPercent': 0.0091},
#    {'symbol': '00939',
#     'holdingName': 'China Construction Bank Corp Class H',
#     'holdingPercent': 0.0084}],
#   'bondHoldings': {'maturity': None,
#    'duration': None,
#    'creditQuality': None,
#    'maturityCat': None,
#    'durationCat': None,
#    'creditQualityCat': None},
#   'bondRatings': [{'bb': 0},
#    {'aa': 0},
#    {'aaa': 0},
#    {'a': 0},
#    {'other': 0},
#    {'b': 0},
#    {'bbb': 0},
#    {'below_b': 0},
#    {'us_government': 0}],
#   'equityHoldings': {'priceToCashflow': 10.89,
#    'priceToSales': 1.38,
#    'priceToBookCat': None,
#    'priceToEarningsCat': None,
#    'medianMarketCapCat': None,
#    'threeYearEarningsGrowthCat': None,
#    'threeYearEarningsGrowth': None,
#    'medianMarketCap': None,
#    'priceToEarnings': 16.44,
#    'priceToBook': 2.07,
#    'priceToSalesCat': None,
#    'priceToCashflowCat': None},
#   'otherPosition': None,
#   'cashPosition': None,
#   'stockPosition': 0.9952,
#   'regularMarketPrice': 50.39,
#   'preMarketPrice': 50.2,
#   'logo_url': ''},
#  {'exchange': 'PCX',
#   'shortName': 'Vanguard FTSE Developed Markets',
#   'longName': 'Vanguard FTSE Developed Markets Index Fund ETF Shares',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-18000000',
#   'quoteType': 'ETF',
#   'symbol': 'VEA',
#   'messageBoardId': 'finmb_28121289',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': None,
#   'beta3Year': 1.04,
#   'profitMargins': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'fundInceptionDate': 1184889600,
#   'annualReportExpenseRatio': None,
#   'totalAssets': 157477650432,
#   'bookValue': None,
#   'fundFamily': 'Vanguard',
#   'lastFiscalYearEnd': None,
#   'netIncomeToCommon': None,
#   'trailingEps': None,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': None,
#   'nextFiscalYearEnd': None,
#   'yield': 0.0249,
#   'mostRecentQuarter': None,
#   'enterpriseValue': None,
#   'priceHint': 2,
#   'threeYearAverageReturn': 0.1274,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': 'Exchange Traded Fund',
#   'lastDividendDate': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'maxAge': 1,
#   'lastCapGain': None,
#   'category': 'Foreign Large Blend',
#   'fiveYearAverageReturn': 0.10609999,
#   'phone': '866-499-8473',
#   'longBusinessSummary': 'The investment seeks to track the performance of the FTSE Developed All Cap ex US Index.\n The fund employs an indexing investment approach designed to track the performance of the FTSE Developed All Cap ex US Index, a market-capitalization-weighted index that is made up of approximately 3865 common stocks of large-, mid-, and small-cap companies located in Canada and the major markets of Europe and the Pacific region. The adviser attempts to replicate the target index by investing all, or substantially all, of its assets in the stocks that make up the index, holding each stock in approximately the same proportion as its weighting in the index.',
#   'companyOfficers': [],
#   'previousClose': 51.44,
#   'regularMarketOpen': 51.45,
#   'twoHundredDayAverage': 51.3996,
#   'trailingAnnualDividendYield': None,
#   'payoutRatio': None,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 51.55,
#   'navPrice': 51.6,
#   'averageDailyVolume10Day': 16646710,
#   'regularMarketPreviousClose': 51.44,
#   'fiftyDayAverage': 51.4922,
#   'trailingAnnualDividendRate': None,
#   'open': 51.45,
#   'toCurrency': None,
#   'averageVolume10days': 16646710,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': None,
#   'exDividendDate': None,
#   'beta': None,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 51.32,
#   'currency': 'USD',
#   'regularMarketVolume': 14731189,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': None,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 9093661,
#   'dayLow': 51.32,
#   'ask': 51.5,
#   'askSize': 39400,
#   'volume': 14731189,
#   'fiftyTwoWeekHigh': 53.49,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 45.6,
#   'bid': 51.47,
#   'tradeable': False,
#   'dividendYield': None,
#   'bidSize': 38800,
#   'dayHigh': 51.55,
#   'preferredPosition': None,
#   'bondPosition': 0,
#   'convertiblePosition': None,
#   'sectorWeightings': [{'realestate': 0.0404},
#    {'consumer_cyclical': 0.11310001},
#    {'basic_materials': 0.082399994},
#    {'consumer_defensive': 0.0861},
#    {'technology': 0.1167},
#    {'communication_services': 0.0541},
#    {'financial_services': 0.1739},
#    {'utilities': 0.031},
#    {'industrials': 0.1547},
#    {'energy': 0.0417},
#    {'healthcare': 0.106000006}],
#   'holdings': [{'symbol': 'NESN',
#     'holdingName': 'Nestle SA',
#     'holdingPercent': 0.015},
#    {'symbol': '005930.KS',
#     'holdingName': 'Samsung Electronics Co Ltd',
#     'holdingPercent': 0.0139999995},
#    {'symbol': 'ASML',
#     'holdingName': 'ASML Holding NV',
#     'holdingPercent': 0.0116},
#    {'symbol': 'ROG',
#     'holdingName': 'Roche Holding AG',
#     'holdingPercent': 0.011},
#    {'symbol': '7203',
#     'holdingName': 'Toyota Motor Corp',
#     'holdingPercent': 0.0092},
#    {'symbol': 'MC.PA',
#     'holdingName': 'LVMH Moet Hennessy Louis Vuitton SE',
#     'holdingPercent': 0.0084},
#    {'symbol': 'NOVN', 'holdingName': 'Novartis AG', 'holdingPercent': 0.0082},
#    {'symbol': 'SHOP.TO',
#     'holdingName': 'Shopify Inc A',
#     'holdingPercent': 0.0069999998},
#    {'symbol': 'AZN.L',
#     'holdingName': 'AstraZeneca PLC',
#     'holdingPercent': 0.0067000003},
#    {'symbol': 'SAP.DE',
#     'holdingName': 'SAP SE',
#     'holdingPercent': 0.0066000004}],
#   'bondHoldings': {'maturity': None,
#    'duration': None,
#    'creditQuality': None,
#    'maturityCat': None,
#    'durationCat': None,
#    'creditQualityCat': None},
#   'bondRatings': [{'bb': 0},
#    {'aa': 0},
#    {'aaa': 0},
#    {'a': 0},
#    {'other': 0},
#    {'b': 0},
#    {'bbb': 0},
#    {'below_b': 0},
#    {'us_government': 0}],
#   'equityHoldings': {'priceToCashflow': 10.2,
#    'priceToSales': 1.44,
#    'priceToBookCat': None,
#    'priceToEarningsCat': None,
#    'medianMarketCapCat': None,
#    'threeYearEarningsGrowthCat': None,
#    'threeYearEarningsGrowth': None,
#    'medianMarketCap': None,
#    'priceToEarnings': 19.25,
#    'priceToBook': 1.76,
#    'priceToSalesCat': None,
#    'priceToCashflowCat': None},
#   'otherPosition': None,
#   'cashPosition': None,
#   'stockPosition': 0.9973,
#   'regularMarketPrice': 51.51,
#   'preMarketPrice': 51.45,
#   'logo_url': ''},
#  {'exchange': 'NGM',
#   'shortName': 'Invesco QQQ Trust, Series 1',
#   'longName': 'Invesco QQQ Trust',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-18000000',
#   'quoteType': 'ETF',
#   'symbol': 'QQQ',
#   'messageBoardId': 'finmb_8108558',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': None,
#   'beta3Year': 1.02,
#   'profitMargins': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'fundInceptionDate': 921024000,
#   'annualReportExpenseRatio': None,
#   'totalAssets': 192853655552,
#   'bookValue': None,
#   'fundFamily': 'Invesco',
#   'lastFiscalYearEnd': None,
#   'netIncomeToCommon': None,
#   'trailingEps': None,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': None,
#   'nextFiscalYearEnd': None,
#   'yield': 0.0046,
#   'mostRecentQuarter': None,
#   'enterpriseValue': None,
#   'priceHint': 2,
#   'threeYearAverageReturn': 0.36810002,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': 'Exchange Traded Fund',
#   'lastDividendDate': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'maxAge': 1,
#   'lastCapGain': None,
#   'category': 'Large Growth',
#   'fiveYearAverageReturn': 0.285,
#   'phone': '800-983-0903',
#   'longBusinessSummary': 'The investment seeks investment results that generally correspond to the price and yield performance of the NASDAQ-100 IndexÂ®.\n To maintain the correspondence between the composition and weights of the securities in the trust (the "securities") and the stocks in the NASDAQ-100 IndexÂ®, the adviser adjusts the securities from time to time to conform to periodic changes in the identity and/or relative weights of index securities. The composition and weighting of the securities portion of a portfolio deposit are also adjusted to conform to changes in the index.',
#   'companyOfficers': [],
#   'previousClose': 397.83,
#   'regularMarketOpen': 398.17,
#   'twoHundredDayAverage': 354.68484,
#   'trailingAnnualDividendYield': 0.0040972275,
#   'payoutRatio': None,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 399.82,
#   'navPrice': 399.26,
#   'averageDailyVolume10Day': 69523340,
#   'regularMarketPreviousClose': 397.83,
#   'fiftyDayAverage': 381.5708,
#   'trailingAnnualDividendRate': 1.63,
#   'open': 398.17,
#   'toCurrency': None,
#   'averageVolume10days': 69523340,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': None,
#   'exDividendDate': None,
#   'beta': None,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 396.22,
#   'currency': 'USD',
#   'trailingPE': 4.6907535,
#   'regularMarketVolume': 38762180,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': None,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 47429807,
#   'dayLow': 396.22,
#   'ask': 399.77,
#   'askSize': 900,
#   'volume': 38762180,
#   'fiftyTwoWeekHigh': 408.71,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 297.45,
#   'bid': 399.45,
#   'tradeable': False,
#   'dividendYield': None,
#   'bidSize': 1100,
#   'dayHigh': 399.82,
#   'preferredPosition': None,
#   'bondPosition': 0,
#   'convertiblePosition': None,
#   'sectorWeightings': [{'realestate': 0},
#    {'consumer_cyclical': 0.16430001},
#    {'basic_materials': 0},
#    {'consumer_defensive': 0.045500003},
#    {'technology': 0.4571},
#    {'communication_services': 0.1965},
#    {'financial_services': 0.023},
#    {'utilities': 0.0088},
#    {'industrials': 0.036199998},
#    {'energy': 0},
#    {'healthcare': 0.0688}],
#   'holdings': [{'symbol': 'AAPL',
#     'holdingName': 'Apple Inc',
#     'holdingPercent': 0.11270001},
#    {'symbol': 'MSFT',
#     'holdingName': 'Microsoft Corp',
#     'holdingPercent': 0.1011},
#    {'symbol': 'AMZN',
#     'holdingName': 'Amazon.com Inc',
#     'holdingPercent': 0.0779},
#    {'symbol': 'GOOG',
#     'holdingName': 'Alphabet Inc Class C',
#     'holdingPercent': 0.0419},
#    {'symbol': 'FB',
#     'holdingName': 'Facebook Inc Class A',
#     'holdingPercent': 0.0404},
#    {'symbol': 'TSLA', 'holdingName': 'Tesla Inc', 'holdingPercent': 0.039},
#    {'symbol': 'GOOGL',
#     'holdingName': 'Alphabet Inc Class A',
#     'holdingPercent': 0.0387},
#    {'symbol': 'NVDA', 'holdingName': 'NVIDIA Corp', 'holdingPercent': 0.0378},
#    {'symbol': 'PYPL',
#     'holdingName': 'PayPal Holdings Inc',
#     'holdingPercent': 0.023},
#    {'symbol': 'ADBE', 'holdingName': 'Adobe Inc', 'holdingPercent': 0.0215}],
#   'bondHoldings': {'maturity': None,
#    'duration': None,
#    'creditQuality': None,
#    'maturityCat': None,
#    'durationCat': None,
#    'creditQualityCat': None},
#   'bondRatings': [{'bb': 0},
#    {'aa': 0},
#    {'aaa': 0},
#    {'a': 0},
#    {'other': 0},
#    {'b': 0},
#    {'bbb': 0},
#    {'below_b': 0},
#    {'us_government': 0}],
#   'equityHoldings': {'priceToCashflow': 22.87,
#    'priceToSales': 4.61,
#    'priceToBookCat': None,
#    'priceToEarningsCat': None,
#    'medianMarketCapCat': None,
#    'threeYearEarningsGrowthCat': None,
#    'threeYearEarningsGrowth': None,
#    'medianMarketCap': None,
#    'priceToEarnings': 33.89,
#    'priceToBook': 8.93,
#    'priceToSalesCat': None,
#    'priceToCashflowCat': None},
#   'otherPosition': None,
#   'cashPosition': None,
#   'stockPosition': 1,
#   'regularMarketPrice': 399.61,
#   'preMarketPrice': 398.16,
#   'logo_url': ''},
#  {'exchange': 'PCX',
#   'shortName': 'iShares Core S&P 500 ETF',
#   'longName': 'iShares Core S&P 500 ETF',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-18000000',
#   'quoteType': 'ETF',
#   'symbol': 'IVV',
#   'messageBoardId': 'finmb_8797798',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': None,
#   'beta3Year': 1,
#   'profitMargins': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'fundInceptionDate': 958348800,
#   'annualReportExpenseRatio': None,
#   'totalAssets': 305292017664,
#   'bookValue': None,
#   'fundFamily': 'iShares',
#   'lastFiscalYearEnd': None,
#   'netIncomeToCommon': None,
#   'trailingEps': None,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': None,
#   'nextFiscalYearEnd': None,
#   'yield': 0.0125,
#   'mostRecentQuarter': None,
#   'enterpriseValue': None,
#   'priceHint': 2,
#   'threeYearAverageReturn': 0.2337,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': 'Exchange Traded Fund',
#   'lastDividendDate': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'maxAge': 1,
#   'lastCapGain': None,
#   'category': 'Large Blend',
#   'fiveYearAverageReturn': 0.1844,
#   'phone': '800-474-2737',
#   'longBusinessSummary': 'The investment seeks to track the investment results of the S&P 500 composed of large-capitalization U.S. equities.\n The index measures the performance of the large-capitalization sector of the U.S. equity market, as determined by SPDJI. The fund generally will invest at least 80% of its assets in the component securities of its index and in investments that have economic characteristics that are substantially identical to the component securities of its index and may invest up to 20% of its assets in certain futures, options and swap contracts, cash and cash equivalents.',
#   'companyOfficers': [],
#   'previousClose': 470.19,
#   'regularMarketOpen': 470.595,
#   'twoHundredDayAverage': 432.10275,
#   'trailingAnnualDividendYield': 0.012097238,
#   'payoutRatio': None,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 471.88,
#   'navPrice': 469.35,
#   'averageDailyVolume10Day': 7677900,
#   'regularMarketPreviousClose': 470.19,
#   'fiftyDayAverage': 455.9252,
#   'trailingAnnualDividendRate': 5.688,
#   'open': 470.595,
#   'toCurrency': None,
#   'averageVolume10days': 7677900,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': None,
#   'exDividendDate': None,
#   'beta': None,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 468.77,
#   'currency': 'USD',
#   'trailingPE': 3.383428,
#   'regularMarketVolume': 4529652,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': None,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 4647871,
#   'dayLow': 468.77,
#   'ask': 471.63,
#   'askSize': 1000,
#   'volume': 4529652,
#   'fiftyTwoWeekHigh': 475.5,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 363.38,
#   'bid': 471.63,
#   'tradeable': False,
#   'dividendYield': None,
#   'bidSize': 800,
#   'dayHigh': 471.88,
#   'preferredPosition': None,
#   'bondPosition': 0,
#   'convertiblePosition': None,
#   'sectorWeightings': [{'realestate': 0.026300002},
#    {'consumer_cyclical': 0.1168},
#    {'basic_materials': 0.0222},
#    {'consumer_defensive': 0.0619},
#    {'technology': 0.2502},
#    {'communication_services': 0.114700004},
#    {'financial_services': 0.1387},
#    {'utilities': 0.025},
#    {'industrials': 0.0853},
#    {'energy': 0.0241},
#    {'healthcare': 0.1348}],
#   'holdings': [{'symbol': 'AAPL',
#     'holdingName': 'Apple Inc',
#     'holdingPercent': 0.062},
#    {'symbol': 'MSFT',
#     'holdingName': 'Microsoft Corp',
#     'holdingPercent': 0.0592},
#    {'symbol': 'AMZN',
#     'holdingName': 'Amazon.com Inc',
#     'holdingPercent': 0.0387},
#    {'symbol': 'FB',
#     'holdingName': 'Facebook Inc Class A',
#     'holdingPercent': 0.023699999},
#    {'symbol': 'GOOGL',
#     'holdingName': 'Alphabet Inc Class A',
#     'holdingPercent': 0.0227},
#    {'symbol': 'GOOG',
#     'holdingName': 'Alphabet Inc Class C',
#     'holdingPercent': 0.0216},
#    {'symbol': 'TSLA', 'holdingName': 'Tesla Inc', 'holdingPercent': 0.0148},
#    {'symbol': 'NVDA',
#     'holdingName': 'NVIDIA Corp',
#     'holdingPercent': 0.0145000005},
#    {'symbol': 'BRK.B',
#     'holdingName': 'Berkshire Hathaway Inc Class B',
#     'holdingPercent': 0.014099999},
#    {'symbol': 'JPM',
#     'holdingName': 'JPMorgan Chase & Co',
#     'holdingPercent': 0.0126}],
#   'bondHoldings': {'maturity': None,
#    'duration': None,
#    'creditQuality': None,
#    'maturityCat': None,
#    'durationCat': None,
#    'creditQualityCat': None},
#   'bondRatings': [{'bb': 0},
#    {'aa': 0},
#    {'aaa': 0},
#    {'a': 0},
#    {'other': 0},
#    {'b': 0},
#    {'bbb': 0},
#    {'below_b': 0},
#    {'us_government': 0}],
#   'equityHoldings': {'priceToCashflow': 18.14,
#    'priceToSales': 2.87,
#    'priceToBookCat': None,
#    'priceToEarningsCat': None,
#    'medianMarketCapCat': None,
#    'threeYearEarningsGrowthCat': None,
#    'threeYearEarningsGrowth': None,
#    'medianMarketCap': None,
#    'priceToEarnings': 25.32,
#    'priceToBook': 4.48,
#    'priceToSalesCat': None,
#    'priceToCashflowCat': None},
#   'otherPosition': None,
#   'cashPosition': None,
#   'stockPosition': 0.9976,
#   'regularMarketPrice': 471.43,
#   'preMarketPrice': 470.55,
#   'logo_url': ''},
#  {'exchange': 'BTS',
#   'shortName': 'iShares Core MSCI EAFE ETF',
#   'longName': 'iShares Core MSCI EAFE ETF',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-18000000',
#   'quoteType': 'ETF',
#   'symbol': 'IEFA',
#   'messageBoardId': 'finmb_223235653',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': None,
#   'beta3Year': 1.01,
#   'profitMargins': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'fundInceptionDate': 1350518400,
#   'annualReportExpenseRatio': None,
#   'totalAssets': 95780700160,
#   'bookValue': None,
#   'fundFamily': 'iShares',
#   'lastFiscalYearEnd': None,
#   'netIncomeToCommon': None,
#   'trailingEps': None,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': None,
#   'nextFiscalYearEnd': None,
#   'yield': 0.0228,
#   'mostRecentQuarter': None,
#   'enterpriseValue': None,
#   'priceHint': 2,
#   'threeYearAverageReturn': 0.120799996,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': 'Exchange Traded Fund',
#   'lastDividendDate': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'maxAge': 1,
#   'lastCapGain': None,
#   'category': 'Foreign Large Blend',
#   'fiveYearAverageReturn': 0.1066,
#   'phone': '800-474-2737',
#   'longBusinessSummary': 'The investment seeks to track the investment results of the MSCI EAFE IMI Index composed of large-, mid- and small-capitalization developed market equities, excluding the U.S. and Canada.\n The fund generally will invest at least 80% of its assets in the component securities of the underlying index and in investments that have economic characteristics that are substantially identical to the component securities of the underlying index. The index is designed to measure large-, mid- and small-capitalization equity market performance and includes stocks from Europe, Australasia and the Far East.',
#   'companyOfficers': [],
#   'previousClose': 75.23,
#   'regularMarketOpen': 75.29,
#   'twoHundredDayAverage': 75.23585,
#   'trailingAnnualDividendYield': None,
#   'payoutRatio': None,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 75.44,
#   'navPrice': 75.62,
#   'averageDailyVolume10Day': 14835630,
#   'regularMarketPreviousClose': 75.23,
#   'fiftyDayAverage': 75.5134,
#   'trailingAnnualDividendRate': None,
#   'open': 75.29,
#   'toCurrency': None,
#   'averageVolume10days': 14835630,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': None,
#   'exDividendDate': None,
#   'beta': None,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 75.1,
#   'currency': 'USD',
#   'regularMarketVolume': 7991098,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': None,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 9137631,
#   'dayLow': 75.1,
#   'ask': 75.71,
#   'askSize': 1800,
#   'volume': 7991098,
#   'fiftyTwoWeekHigh': 78.34,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 66.88,
#   'bid': 74.94,
#   'tradeable': False,
#   'dividendYield': None,
#   'bidSize': 900,
#   'dayHigh': 75.44,
#   'preferredPosition': None,
#   'bondPosition': 0,
#   'convertiblePosition': None,
#   'sectorWeightings': [{'realestate': 0.0431},
#    {'consumer_cyclical': 0.1196},
#    {'basic_materials': 0.0793},
#    {'consumer_defensive': 0.097799994},
#    {'technology': 0.09810001},
#    {'communication_services': 0.0553},
#    {'financial_services': 0.1591},
#    {'utilities': 0.0325},
#    {'industrials': 0.16319999},
#    {'energy': 0.0319},
#    {'healthcare': 0.1201}],
#   'holdings': [{'symbol': 'NESN',
#     'holdingName': 'Nestle SA',
#     'holdingPercent': 0.0177},
#    {'symbol': 'ASML',
#     'holdingName': 'ASML Holding NV',
#     'holdingPercent': 0.0143},
#    {'symbol': 'ROG',
#     'holdingName': 'Roche Holding AG',
#     'holdingPercent': 0.013099999},
#    {'symbol': 'MC.PA',
#     'holdingName': 'LVMH Moet Hennessy Louis Vuitton SE',
#     'holdingPercent': 0.0108},
#    {'symbol': 'NOVN', 'holdingName': 'Novartis AG', 'holdingPercent': 0.01},
#    {'symbol': '7203',
#     'holdingName': 'Toyota Motor Corp',
#     'holdingPercent': 0.0092},
#    {'symbol': 'AZN.L',
#     'holdingName': 'AstraZeneca PLC',
#     'holdingPercent': 0.0078},
#    {'symbol': 'ULVR.L',
#     'holdingName': 'Unilever PLC',
#     'holdingPercent': 0.0076},
#    {'symbol': '01299.HK',
#     'holdingName': 'AIA Group Ltd',
#     'holdingPercent': 0.0074},
#    {'symbol': 'SAP.DE', 'holdingName': 'SAP SE', 'holdingPercent': 0.0073}],
#   'bondHoldings': {'maturity': None,
#    'duration': None,
#    'creditQuality': None,
#    'maturityCat': None,
#    'durationCat': None,
#    'creditQualityCat': None},
#   'bondRatings': [{'bb': 0},
#    {'aa': 0},
#    {'aaa': 0},
#    {'a': 0},
#    {'other': 0},
#    {'b': 0},
#    {'bbb': 0},
#    {'below_b': 0},
#    {'us_government': 0}],
#   'equityHoldings': {'priceToCashflow': 10.62,
#    'priceToSales': 1.47,
#    'priceToBookCat': None,
#    'priceToEarningsCat': None,
#    'medianMarketCapCat': None,
#    'threeYearEarningsGrowthCat': None,
#    'threeYearEarningsGrowth': None,
#    'medianMarketCap': None,
#    'priceToEarnings': 20.08,
#    'priceToBook': 1.8,
#    'priceToSalesCat': None,
#    'priceToCashflowCat': None},
#   'otherPosition': None,
#   'cashPosition': None,
#   'stockPosition': 0.97550005,
#   'regularMarketPrice': 75.37,
#   'preMarketPrice': 73.63,
#   'logo_url': ''},
#  {'exchange': 'PCX',
#   'shortName': 'iShares MSCI EAFE ETF',
#   'longName': 'iShares MSCI EAFE ETF',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-18000000',
#   'quoteType': 'ETF',
#   'symbol': 'EFA',
#   'messageBoardId': 'finmb_8797589',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': None,
#   'beta3Year': 0.99,
#   'profitMargins': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'fundInceptionDate': 997747200,
#   'annualReportExpenseRatio': None,
#   'totalAssets': 58152398848,
#   'bookValue': None,
#   'fundFamily': 'iShares',
#   'lastFiscalYearEnd': None,
#   'netIncomeToCommon': None,
#   'trailingEps': None,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': None,
#   'nextFiscalYearEnd': None,
#   'yield': 0.0223,
#   'mostRecentQuarter': None,
#   'enterpriseValue': None,
#   'priceHint': 2,
#   'threeYearAverageReturn': 0.1166,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': 'Exchange Traded Fund',
#   'lastDividendDate': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'maxAge': 1,
#   'lastCapGain': None,
#   'category': 'Foreign Large Blend',
#   'fiveYearAverageReturn': 0.1024,
#   'phone': '800-474-2737',
#   'longBusinessSummary': 'The investment seeks to track the investment results of the MSCI EAFE Index composed of large- and mid-capitalization developed market equities, excluding the U.S. and Canada.\n The fund generally invests at least 80% of its assets in securities of the underlying index and in depositary receipts representing securities of the underlying index. The index measures the equity market performance of developed markets outside of the U.S. and Canada. The underlying index may include large- or mid-capitalization companies.',
#   'companyOfficers': [],
#   'previousClose': 79.41,
#   'regularMarketOpen': 79.47,
#   'twoHundredDayAverage': 79.1655,
#   'trailingAnnualDividendYield': 0.022176048,
#   'payoutRatio': None,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 79.68,
#   'navPrice': 79.75,
#   'averageDailyVolume10Day': 36086050,
#   'regularMarketPreviousClose': 79.41,
#   'fiftyDayAverage': 79.5048,
#   'trailingAnnualDividendRate': 1.761,
#   'open': 79.47,
#   'toCurrency': None,
#   'averageVolume10days': 36086050,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': None,
#   'exDividendDate': None,
#   'beta': None,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 79.28,
#   'currency': 'USD',
#   'trailingPE': 29.62025,
#   'regularMarketVolume': 20906984,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': None,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 24256142,
#   'dayLow': 79.28,
#   'ask': 79.93,
#   'askSize': 36900,
#   'volume': 20906984,
#   'fiftyTwoWeekHigh': 82.29,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 70.67,
#   'bid': 79.56,
#   'tradeable': False,
#   'dividendYield': None,
#   'bidSize': 47300,
#   'dayHigh': 79.68,
#   'preferredPosition': None,
#   'bondPosition': 0,
#   'convertiblePosition': None,
#   'sectorWeightings': [{'realestate': 0.0295},
#    {'consumer_cyclical': 0.1102},
#    {'basic_materials': 0.0779},
#    {'consumer_defensive': 0.1024},
#    {'technology': 0.1029},
#    {'communication_services': 0.057800002},
#    {'financial_services': 0.1668},
#    {'utilities': 0.033800002},
#    {'industrials': 0.1532},
#    {'energy': 0.033099998},
#    {'healthcare': 0.13239999}],
#   'holdings': [{'symbol': 'NESN',
#     'holdingName': 'Nestle SA',
#     'holdingPercent': 0.0208},
#    {'symbol': 'ASML',
#     'holdingName': 'ASML Holding NV',
#     'holdingPercent': 0.0199},
#    {'symbol': 'ROG',
#     'holdingName': 'Roche Holding AG',
#     'holdingPercent': 0.0161},
#    {'symbol': 'NOVN',
#     'holdingName': 'Novartis AG',
#     'holdingPercent': 0.0117999995},
#    {'symbol': 'MC.PA',
#     'holdingName': 'LVMH Moet Hennessy Louis Vuitton SE',
#     'holdingPercent': 0.0117},
#    {'symbol': '7203',
#     'holdingName': 'Toyota Motor Corp',
#     'holdingPercent': 0.0106},
#    {'symbol': 'AZN.L',
#     'holdingName': 'AstraZeneca PLC',
#     'holdingPercent': 0.0104},
#    {'symbol': 'NOVO B',
#     'holdingName': 'Novo Nordisk A/S Class B',
#     'holdingPercent': 0.0097},
#    {'symbol': 'SAP.DE', 'holdingName': 'SAP SE', 'holdingPercent': 0.009},
#    {'symbol': 'ULVR.L',
#     'holdingName': 'Unilever PLC',
#     'holdingPercent': 0.0083}],
#   'bondHoldings': {'maturity': None,
#    'duration': None,
#    'creditQuality': None,
#    'maturityCat': None,
#    'durationCat': None,
#    'creditQualityCat': None},
#   'bondRatings': [{'bb': 0},
#    {'aa': 0},
#    {'aaa': 0},
#    {'a': 0},
#    {'other': 0},
#    {'b': 0},
#    {'bbb': 0},
#    {'below_b': 0},
#    {'us_government': 0}],
#   'equityHoldings': {'priceToCashflow': 10.34,
#    'priceToSales': 1.45,
#    'priceToBookCat': None,
#    'priceToEarningsCat': None,
#    'medianMarketCapCat': None,
#    'threeYearEarningsGrowthCat': None,
#    'threeYearEarningsGrowth': None,
#    'medianMarketCap': None,
#    'priceToEarnings': 17.24,
#    'priceToBook': 1.86,
#    'priceToSalesCat': None,
#    'priceToCashflowCat': None},
#   'otherPosition': None,
#   'cashPosition': None,
#   'stockPosition': 0.9913,
#   'regularMarketPrice': 79.56,
#   'preMarketPrice': 79.47,
#   'logo_url': ''},
#  {'exchange': 'PCX',
#   'shortName': 'iShares Core U.S. Aggregate Bon',
#   'longName': 'iShares Core U.S. Aggregate Bond ETF',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-18000000',
#   'quoteType': 'ETF',
#   'symbol': 'AGG',
#   'messageBoardId': 'finmb_6180097',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': None,
#   'beta3Year': 1,
#   'profitMargins': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'fundInceptionDate': 1064188800,
#   'annualReportExpenseRatio': None,
#   'totalAssets': 88802074624,
#   'bookValue': None,
#   'fundFamily': 'iShares',
#   'lastFiscalYearEnd': None,
#   'netIncomeToCommon': None,
#   'trailingEps': None,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': None,
#   'nextFiscalYearEnd': None,
#   'yield': 0.0195,
#   'mostRecentQuarter': None,
#   'enterpriseValue': None,
#   'priceHint': 2,
#   'threeYearAverageReturn': 0.051,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': 'Exchange Traded Fund',
#   'lastDividendDate': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'maxAge': 1,
#   'lastCapGain': None,
#   'category': 'Intermediate-Term Bond',
#   'fiveYearAverageReturn': 0.033800002,
#   'phone': '800-474-2737',
#   'longBusinessSummary': 'The investment seeks to track the investment results of the Bloomberg Barclays U.S. Aggregate Bond Index.\n The index measures the performance of the total U.S. investment-grade bond market. The fund generally invests at least 90% of its net assets in component securities of its underlying index and in investments that have economic characteristics that are substantially identical to the economic characteristics of the component securities of its underlying index.',
#   'companyOfficers': [],
#   'previousClose': 114.49,
#   'regularMarketOpen': 114.37,
#   'twoHundredDayAverage': 114.92645,
#   'trailingAnnualDividendYield': 0.021661282,
#   'payoutRatio': None,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 114.37,
#   'navPrice': 113.93,
#   'averageDailyVolume10Day': 8442850,
#   'regularMarketPreviousClose': 114.49,
#   'fiftyDayAverage': 114.4752,
#   'trailingAnnualDividendRate': 2.48,
#   'open': 114.37,
#   'toCurrency': None,
#   'averageVolume10days': 8442850,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': None,
#   'exDividendDate': None,
#   'beta': None,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 114.05,
#   'currency': 'USD',
#   'trailingPE': 145.65051,
#   'regularMarketVolume': 8033275,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': None,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 6152493,
#   'dayLow': 114.05,
#   'ask': 114.75,
#   'askSize': 38800,
#   'volume': 8033275,
#   'fiftyTwoWeekHigh': 118.24,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 113.2,
#   'bid': 114.02,
#   'tradeable': False,
#   'dividendYield': None,
#   'bidSize': 21500,
#   'dayHigh': 114.37,
#   'preferredPosition': None,
#   'bondPosition': 0.8525,
#   'convertiblePosition': None,
#   'sectorWeightings': [{'realestate': 0},
#    {'consumer_cyclical': 0},
#    {'basic_materials': 0},
#    {'consumer_defensive': 0},
#    {'technology': 0},
#    {'communication_services': 0},
#    {'financial_services': 0},
#    {'utilities': 0},
#    {'industrials': 0},
#    {'energy': 0},
#    {'healthcare': 0}],
#   'holdings': [{'symbol': 'BISXX',
#     'holdingName': 'BlackRock Cash Funds Instl SL Agency',
#     'holdingPercent': 0.082100004},
#    {'symbol': '',
#     'holdingName': 'Federal National Mortgage Association 2%',
#     'holdingPercent': 0.013300001},
#    {'symbol': '',
#     'holdingName': 'Federal National Mortgage Association 2.5%',
#     'holdingPercent': 0.0084},
#    {'symbol': '',
#     'holdingName': 'Government National Mortgage Association 2.5%',
#     'holdingPercent': 0.0073},
#    {'symbol': '',
#     'holdingName': 'Federal National Mortgage Association 1.5%',
#     'holdingPercent': 0.0058},
#    {'symbol': '',
#     'holdingName': 'United States Treasury Notes 0.75%',
#     'holdingPercent': 0.0056},
#    {'symbol': '',
#     'holdingName': 'United States Treasury Bonds 1.88%',
#     'holdingPercent': 0.0055},
#    {'symbol': '',
#     'holdingName': 'United States Treasury Notes 0.38%',
#     'holdingPercent': 0.0055}],
#   'bondHoldings': {'maturity': 8.3,
#    'duration': 6.56,
#    'creditQuality': None,
#    'maturityCat': None,
#    'durationCat': None,
#    'creditQualityCat': None},
#   'bondRatings': [{'bb': 0},
#    {'aa': 0.0292},
#    {'aaa': 0.6892},
#    {'a': 0.1116},
#    {'other': 0.0163},
#    {'b': 0},
#    {'bbb': 0.1538},
#    {'below_b': 0},
#    {'us_government': 0}],
#   'equityHoldings': {'priceToCashflow': 0,
#    'priceToSales': 0,
#    'priceToBookCat': None,
#    'priceToEarningsCat': None,
#    'medianMarketCapCat': None,
#    'threeYearEarningsGrowthCat': None,
#    'threeYearEarningsGrowth': None,
#    'medianMarketCap': None,
#    'priceToEarnings': 0,
#    'priceToBook': 0,
#    'priceToSalesCat': None,
#    'priceToCashflowCat': None},
#   'otherPosition': None,
#   'cashPosition': None,
#   'stockPosition': 0,
#   'regularMarketPrice': 114.19,
#   'preMarketPrice': 114.37,
#   'logo_url': ''}]

# %%
qqq = yf.Ticker("QQQ") #get stock info
qqq_data = qqq.history(period="max") #get historical market data of QQQ
qqq_data[1:10]
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 1999-03-11  44.611567  44.869045  43.635858  44.503155   9688600        0.0
# 1999-03-12  44.340536  44.367639  43.066694  43.419033   8743600        0.0
# 1999-03-15  43.744247  44.719955  43.283495  44.665749   6369000        0.0
# 1999-03-16  44.855487  45.234929  44.367633  45.045208   4905800        0.0
# 1999-03-17  45.045215  45.099421  44.584463  44.719978   3965000        0.0
# 1999-03-18  44.665778  45.614383  44.652226  45.587280   4848400        0.0
# 1999-03-19  46.183545  46.183545  44.394745  44.421848   7160400        0.0
# 1999-03-22  44.611561  44.719973  43.798471  43.879780   5024800        0.0
# 1999-03-23  43.635868  43.798486  42.253614  42.334923  10962400        0.0
#
#             Stock Splits
# Date
# 1999-03-11           0.0
# 1999-03-12           0.0
# 1999-03-15           0.0
# 1999-03-16           0.0
# 1999-03-17           0.0
# 1999-03-18           0.0
# 1999-03-19           0.0
# 1999-03-22           0.0
# 1999-03-23           0.0

# %%
#show dividens and splits of QQQ. 
#dividends and splits with the dates when they are provided
# Stock split only once in 2000
qqq.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2000-03-20      0.000           2.0
# 2003-12-24      0.014           0.0
# 2004-12-17      0.379           0.0
# 2005-06-17      0.035           0.0
# 2005-12-16      0.101           0.0
# ...               ...           ...
# 2020-06-22      0.424           0.0
# 2020-12-21      0.561           0.0
# 2021-03-22      0.395           0.0
# 2021-06-21      0.397           0.0
# 2021-09-20      0.414           0.0
#
# [70 rows x 2 columns]

# %%
#show major holders of QQQ
qqq.institutional_holders
# Out:
#                         0           1
# 0              Net Assets     192.85B
# 1                     NAV      399.26
# 2          PE Ratio (TTM)        4.69
# 3                   Yield       0.46%
# 4  YTD Daily Total Return      27.57%
# 5       Beta (5Y Monthly)        1.02
# 6     Expense Ratio (net)       0.20%
# 7          Inception Date  1999-03-10

# %%
#show news 
qqq.news
# Out:
# [{'uuid': 'a6ffd016-fc66-3986-8f45-b66158ace49e',
#   'title': '2 Nasdaq ETFs for Q1 2022',
#   'publisher': 'Investopedia',
#   'link': 'https://finance.yahoo.com/m/a6ffd016-fc66-3986-8f45-b66158ace49e/2-nasdaq-etfs-for-q1-2022.html',
#   'providerPublishTime': 1638877169,
#   'type': 'STORY'},
#  {'uuid': '0597e2a4-dcf8-3437-97c1-f02557830eee',
#   'title': 'Unemployment Rate 4.2%, Jobs Strangely Low',
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/unemployment-rate-4-2-jobs-153903725.html',
#   'providerPublishTime': 1638545943,
#   'type': 'STORY'},
#  {'uuid': 'e004aec6-9f5a-4d87-8dda-577a8f3b3a55',
#   'title': 'Stock market news live updates: Wall Street shrugs off second Omicron case, Dow soars over 600 points',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/stock-market-news-live-updates-december-2-2021-234242984.html',
#   'providerPublishTime': 1638479627,
#   'type': 'STORY'},
#  {'uuid': '1331c6e4-071d-46d9-b673-dee29e202399',
#   'title': 'Is Apple stock a major buy right now? This strategist says yes',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/is-apple-stock-a-major-buy-right-now-this-strategist-says-yes-185742460.html',
#   'providerPublishTime': 1638471462,
#   'type': 'STORY'},
#  {'uuid': '59f0c7b8-1968-41de-9199-9e933907a0cb',
#   'title': 'Stock market news live updates: Stocks turn lower with Omicron, inflation in focus',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/stock-market-news-live-updates-december-1-2021-232350209.html',
#   'providerPublishTime': 1638392779,
#   'type': 'STORY'},
#  {'uuid': 'd4b60472-40ac-407e-8cc4-ac44120b7491',
#   'title': 'Stock market news live updates: Stocks fall as investors consider Omicron impact, Powell tapering remarks',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/stock-market-news-live-updates-november-30-2021-231704968.html',
#   'providerPublishTime': 1638306433,
#   'type': 'STORY'},
#  {'uuid': 'b2d22db2-ff11-4d0f-8623-926945b49a7e',
#   'title': "Stock market news live updates: Stocks recoup some losses as Biden says Omicron is 'not a cause for panic’",
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/stock-market-news-live-updates-november-29-2021-124605390.html',
#   'providerPublishTime': 1638219945,
#   'type': 'STORY'},
#  {'uuid': '6a69f2c6-cd9f-34a6-bfee-1db90a338bd4',
#   'title': "Stock market: How to invest amid uncertainty, according to '40 Finance' host Geoff Beers",
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/stock-market-invest-amid-uncertainty-155526656.html',
#   'providerPublishTime': 1638201326,
#   'type': 'VIDEO'}]

# %%
#contains a historical list of recommendations made by analysts
qqq.recommendations

# %%
# download dataframe
data = yf.download("QQQ", start="2017-01-01") #SH Removed End Here As We Want Current Date 
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  119.269997  119.989998  118.889999  119.540001  115.439819
# 2017-01-04  119.669998  120.410004  119.660004  120.190002  116.067535
# 2017-01-05  120.099998  120.949997  120.099998  120.870003  116.724213
# 2017-01-06  121.000000  122.250000  120.690002  121.930000  117.747849
# 2017-01-09  122.029999  122.550003  121.949997  122.330002  118.134132
# ...                ...         ...         ...         ...         ...
# 2021-12-02  385.799988  391.739990  384.339996  389.910004  389.910004
# 2021-12-03  391.309998  392.339996  378.899994  383.130005  383.130005
# 2021-12-06  383.630005  387.600006  379.299988  386.200012  386.200012
# 2021-12-07  393.029999  398.459991  392.989990  397.829987  397.829987
# 2021-12-08  398.170013  399.820007  396.220001  399.609985  399.609985
#
#                Volume
# Date
# 2017-01-03   22307600
# 2017-01-04   19749100
# 2017-01-05   20644300
# 2017-01-06   24074300
# 2017-01-09   18909200
# ...               ...
# 2021-12-02   84416600
# 2021-12-03  105291200
# 2021-12-06   67588800
# 2021-12-07   56005300
# 2021-12-08   38762180
#
# [1243 rows x 6 columns]

# %%
#Function to Get Different Kinds Of Info From a Stock Ticker Directly Through API 
def ticker_info():
    ticker_name = input("Enter Ticker Name")
    ticker_symbol = yf.Ticker(ticker_name)
    ticker_data = ticker_symbol.history(period="max")
    return ticker_data

# %%
ticker_info()
# Out:
# Enter Ticker Name qqq
#                   Open        High         Low       Close     Volume  \
# Date
# 1999-03-10   44.340541   44.367644   43.608759   44.286335    5232000
# 1999-03-11   44.611563   44.869042   43.635854   44.503151    9688600
# 1999-03-12   44.340524   44.367627   43.066682   43.419022    8743600
# 1999-03-15   43.744273   44.719981   43.283521   44.665775    6369000
# 1999-03-16   44.855498   45.234941   44.367644   45.045219    4905800
# ...                ...         ...         ...         ...        ...
# 2021-12-02  385.799988  391.739990  384.339996  389.910004   84416600
# 2021-12-03  391.309998  392.339996  378.899994  383.130005  105291200
# 2021-12-06  383.630005  387.600006  379.299988  386.200012   67588800
# 2021-12-07  393.029999  398.459991  392.989990  397.829987   56005300
# 2021-12-08  398.170013  399.820007  396.220001  399.609985   38762180
#
#             Dividends  Stock Splits
# Date
# 1999-03-10        0.0           0.0
# 1999-03-11        0.0           0.0
# 1999-03-12        0.0           0.0
# 1999-03-15        0.0           0.0
# 1999-03-16        0.0           0.0
# ...               ...           ...
# 2021-12-02        0.0           0.0
# 2021-12-03        0.0           0.0
# 2021-12-06        0.0           0.0
# 2021-12-07        0.0           0.0
# 2021-12-08        0.0           0.0
#
# [5727 rows x 7 columns]

# %%
#Now let us download the data into a data frame and display it.

df = qqq.history(period="max")
df
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1999-03-10   44.340526   44.367629   43.608744   44.286320    5232000
# 1999-03-11   44.611552   44.869030   43.635843   44.503139    9688600
# 1999-03-12   44.340532   44.367635   43.066690   43.419029    8743600
# 1999-03-15   43.744261   44.719970   43.283510   44.665764    6369000
# 1999-03-16   44.855487   45.234929   44.367633   45.045208    4905800
# ...                ...         ...         ...         ...        ...
# 2021-12-02  385.799988  391.739990  384.339996  389.910004   84416600
# 2021-12-03  391.309998  392.339996  378.899994  383.130005  105291200
# 2021-12-06  383.630005  387.600006  379.299988  386.200012   67588800
# 2021-12-07  393.029999  398.459991  392.989990  397.829987   56005300
# 2021-12-08  398.170013  399.820007  396.220001  399.609985   38762180
#
#             Dividends  Stock Splits
# Date
# 1999-03-10        0.0           0.0
# 1999-03-11        0.0           0.0
# 1999-03-12        0.0           0.0
# 1999-03-15        0.0           0.0
# 1999-03-16        0.0           0.0
# ...               ...           ...
# 2021-12-02        0.0           0.0
# 2021-12-03        0.0           0.0
# 2021-12-06        0.0           0.0
# 2021-12-07        0.0           0.0
# 2021-12-08        0.0           0.0
#
# [5727 rows x 7 columns]

# %%
#Reseting the index
df = df.reset_index()
#Converting the datatype to float
for i in ['Open', 'High', 'Close', 'Low']:
    df[i] = df[i].astype('float64')

# %%
#Installing Plotly
# !pip3 install plotly
# Out:
# Requirement already satisfied: plotly in c:\users
07-08T00:00:00","1999-07-09T00:00:00","1999-07-12T00:00:00","1999-07-13T00:00:00","1999-07-14T00:00:00","1999-07-15T00:00:00","1999-07-16T00:00:00","1999-07-19T00:00:00","1999-07-20T00:00:00","1999-07-21T00:00:00","1999-07-22T00:00:00","1999-07-23T00:00:00","1999-07-26T00:00:00","1999-07-27T00:00:00","1999-07-28T00:00:00","1999-07-29T00:00:00","1999-07-30T00:00:00","1999-08-02T00:00:00","1999-08-03T00:00:00","1999-08-04T00:00:00","1999-08-05T00:00:00","1999-08-06T00:00:00","1999-08-09T00:00:00","1999-08-10T00:00:00","1999-08-11T00:00:00","1999-08-12T00:00:00","1999-08-13T00:00:00","1999-08-16T00:00:00","1999-08-17T00:00:00","1999-08-18T00:00:00","1999-08-19T00:00:00","1999-08-20T00:00:00","1999-08-23T00:00:00","1999-08-24T00:00:00","1999-08-25T00:00:00","1999-08-26T00:00:00","1999-08-27T00:00:00","1999-08-30T00:00:00","1999-08-31T00:00:00","1999-09-01T00:00:00","1999-09-02T00:00:00","1999-09-03T00:00:00","1999-09-07T00:00:00","1999-09-08T00:00:00","1999-09-09T00:00:00","1999-09-10T00:00:00","1999-09-13T00:00:00","1999-09-14T00:00:00","1999-09-15T00:00:00","1999-09-16T00:00:00","1999-09-17T00:00:00","1999-09-20T00:00:00","1999-09-21T00:00:00","1999-09-22T00:00:00","1999-09-23T00:00:00","1999-09-24T00:00:00","1999-09-27T00:00:00","1999-09-28T00:00:00","1999-09-29T00:00:00","1999-09-30T00:00:00","1999-10-01T00:00:00","1999-10-04T00:00:00","1999-10-05T00:00:00","1999-10-06T00:00:00","1999-10-07T00:00:00","1999-10-08T00:00:00","1999-10-11T00:00:00","1999-10-12T00:00:00","1999-10-13T00:00:00","1999-10-14T00:00:00","1999-10-15T00:00:00","1999-10-18T00:00:00","1999-10-19T00:00:00","1999-10-20T00:00:00","1999-10- ...

# %%
#Install Elasticsearch loader to import JSON files
# !pip3 install elasticsearch-loader
# Out:
# Requirement already satisfied: elasticsearch-loader in c:\users\sandelemental\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: click-stream==0.0.10 in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch-loader) (0.0.10)
# Requirement already satisfied: click-conf in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch-loader) (0.0.1)
# Requirement already satisfied: elasticsearch>=6 in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch-loader) (7.13.3)
# Requirement already satisfied: click==7.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch-loader) (7.0)
# Requirement already satisfied: certifi in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch>=6->elasticsearch-loader) (2021.10.8)
# Requirement already satisfied: urllib3<2,>=1.21.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch>=6->elasticsearch-loader) (1.26.6)
# Requirement already satisfied: pyaml in c:\users\sandelemental\anaconda3\lib\site-packages (from click-conf->elasticsearch-loader) (21.10.1)
# Requirement already satisfied: PyYAML in c:\users\sandelemental\anaconda3\lib\site-packages (from pyaml->click-conf->elasticsearch-loader) (5.4.1)

# %%
#Import JSON text file (input as lines of strings)
#In elasticsearch, index is like 'database', type is like a 'table'
# !elasticsearch_loader --index out_file --id-field uuid json etf.json --json-lines
# Out:
# {'index': 'out_file', 'id_field': 'uuid', 'bulk_size': 500, 'es_host': ('http://localhost:9200',), 'verify_certs': False, 'use_ssl': False, 'ca_certs': None, 'http_auth': None, 'delete': False, 'update': False, 'progress': False, 'type': '_doc', 'as_child': False, 'with_retry': False, 'index_settings_file': None, 'timeout': 10.0, 'encoding': 'utf-8', 'keys': [], 'es_conn': <Elasticsearch([{'host': 'localhost', 'port': 9200}])>}
# Traceback (most recent call last):
#   File "c:\users\sandelemental\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\sandelemental\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Sandelemental\anaconda3\Scripts\elasticsearch_loader.exe\__main__.py", line 7, in <module>
#   File "c:\users\sandelemental\anaconda3\lib\site-packages\click\core.py", line 764, in __call__
#     return self.main(*args, **kwargs)
#   File "c:\users\sandelemental\anaconda3\lib\site-packages\click\core.py", line 717, in main
#     rv = self.invoke(ctx)
#   File "c:\users\sandelemental\anaconda3\lib\site-packages\click\core.py", line 1137, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "c:\users\sandelemental\anaconda3\lib\site-packages\click\core.py", line 956, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "c:\users\sandelemental\anaconda3\lib\site-packages\click\core.py", line 555, in invoke
#     return callback(*args, **kwargs)
#   File "c:\users\sandelemental\anaconda3\lib\site-packages\click\decorators.py", line 17, in new_func
#     return f(get_current_context(), *args, **kwargs)
#   File "c:\users\sandelemental\anaconda3\lib\site-packages\elasticsearch_loader\__init__.py", line 150, in _json
#     load(lines, ctx.obj)
#   File "c:\users\sandelemental\anaconda3\lib\site-packages\elasticsearch_loader\__init__.py", line 51, in load
#     for i, bulk in enumerate(pbar):
#   File "c:\users\sandelemental\anaconda3\lib\site-packages\click\_termui_impl.py", line 282, in generator
#     for rv in self.iter:
#   File "c:\users\sandelemental\anaconda3\lib\site-packages\elasticsearch_loader\iter.py", line 43, in json_lines_iter
#     yield json.loads(line)
# ValueError: Expected object or value

# %%
#Install elasticsearch Python packages
# !pip3 install elasticsearch
# !pip3 install elasticsearch-dsl
# Out:
# Requirement already satisfied: elasticsearch in c:\users\sandelemental\anaconda3\lib\site-packages (7.13.3)
# Requirement already satisfied: certifi in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch) (2021.10.8)
# Requirement already satisfied: urllib3<2,>=1.21.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch) (1.26.6)
# Requirement already satisfied: elasticsearch-dsl in c:\users\sandelemental\anaconda3\lib\site-packages (7.4.0)
# Requirement already satisfied: elasticsearch<8.0.0,>=7.0.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch-dsl) (7.13.3)
# Requirement already satisfied: python-dateutil in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch-dsl) (2.8.2)
# Requirement already satisfied: six in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch-dsl) (1.16.0)
# Requirement already satisfied: urllib3<2,>=1.21.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch<8.0.0,>=7.0.0->elasticsearch-dsl) (1.26.6)
# Requirement already satisfied: certifi in c:\users\sandelemental\anaconda3\lib\site-packages (from elasticsearch<8.0.0,>=7.0.0->elasticsearch-dsl) (2021.10.8)

# %%
#Connect to Elasticsearch on my machine
#1. Using elasticsearch package

from elasticsearch import Elasticsearch
client = Elasticsearch()

# %%
#Connect to Elasticsearch on my machine
#2. Using elasticsearch-dsl package
from elasticsearch_dsl import connections
client = connections.create_connection()

# %%
# Elasticsearch Queries<br>https://elasticsearch-dsl.readthedocs.io/en/latest/search_dsl.html
from elasticsearch_dsl import Search
from pprint import pprint

#Elasticsearch queries - import etf.json file to Elasticsearch
s = Search().using(client).query("match", shortName = "SPDR S&P 500")
response = s.execute()
#read the etf.json file as dictionary format
for hit in response['hits']['hits']:
    pprint(hit['_source'].to_dict())

# %% [markdown]
# # SOHEIL'S CODE

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (3.12.1)

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.67-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.6.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 38.2 MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Installing collected packages: lxml, yfinance
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed lxml-4.6.4 yfinance-0.1.67

# %%
pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /usr/local/lib/python3.7/dist-packages (0.9.0)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (1.1.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (4.6.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (2.23.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (2021.10.8)

# %%
pip install yahoo_fin --upgrade
# Out:
# Collecting yahoo_fin
#   Downloading yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (2.23.0)
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (1.1.5)
# Collecting feedparser
#   Downloading feedparser-6.0.8-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 8.0 MB/s
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2.10)
# Collecting w3lib
#   Downloading w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-0.2.6-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 2.4 MB/s
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.0.1)
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.62.3)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.8.2)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 49.6 MB/s
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Collecting websockets<10.0,>=9.1
#   Downloading websockets-9.1-cp37-cp37m-manylinux2010_x86_64.whl (103 kB)
#      |████████████████████████████████| 103 kB 52.5 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.10.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->yahoo_fin) (4.6.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (4.6.4)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Building wheels for collected packages: fake-useragent, parse, sgmllib3k
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=7d1468deb91136e62d50e40b231c435b5ef0c7f33fd4e29134fabb23b97272d6
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=2ed077d5f4f88d6a4ac6b2dd3a05ed7df6d0d17ad3d63b4d6f2c43d2eabb4913
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=c47bf9d0791efa85b6b4c4370dbad7006e9d6551a8c4f60323dbe1dd6ffdb542
#   Stored in directory: /root/.cache/pip/wheels/73/ad/a4/0dff4a6ef231fc0dfa12ffbac2a36cebfdddfe059f50e019aa
# Successfully built fake-useragent parse sgmllib3k
# Installing collected packages: websockets, urllib3, pyee, cssselect, w3lib, sgmllib3k, pyquery, pyppeteer, parse, fake-useragent, requests-html, feedparser, yahoo-fin
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed cssselect-1.1.0 fake-useragent-0.1.11 feedparser-6.0.8 parse-1.19.0 pyee-8.2.2 pyppeteer-0.2.6 pyquery-1.4.3 requests-html-0.10.0 sgmllib3k-1.0.0 urllib3-1.25.11 w3lib-1.22.0 websockets-9.1 yahoo-fin-0.8.9.1

# %%
# 1- Historical Prices

# %%
import pymongo
import json
import requests
#retrieving historical prices from Apple.
historical_prices = requests.get('https://financialmodelingprep.com/api/v3/historical-chart/1min/AAPL?apikey=9cd6b96b4b472eb298b9178e91959c51')

# %%
print(historical_prices)
#outcome
# Out:
# <Response [200]>

# %%
client = pymongo.MongoClient("mongodb://pythonforfinance:mypassword@cluster0-shard-00-00-apl4w.mongodb.net:27017,cluster0-shard-00-01-apl4w.mongodb.net:27017,cluster0-shard-00-02-apl4w.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
#connect to  database. It will create database call historical_price
db = client['historical_prices']

# %%
print (db)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01-apl4w.mongodb.net:27017', 'cluster0-shard-00-00-apl4w.mongodb.net:27017', 'cluster0-shard-00-02-apl4w.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'historical_prices')

# %%
# 2-Earnings Surprises

# %%
earnings_surprises = requests.get ('https://financialmodelingprep.com/api/v3/earnings-surprises/AAPL?apikey=9cd6b96b4b472eb298b9178e91959c51')

# %%
earnings_surprises = earnings_surprises.json()

# %%
print(earnings_surprises)
#outcome
# Out:
# [{'date': '2021-10-28', 'symbol': 'AAPL', 'actualEarningResult': 1.24, 'estimatedEarning': 1.24}, {'date': '2021-07-27', 'symbol': 'AAPL', 'actualEarningResult': 1.3, 'estimatedEarning': 1.01}, {'date': '2021-04-28', 'symbol': 'AAPL', 'actualEarningResult': 1.4, 'estimatedEarning': 0.99}, {'date': '2021-01-27', 'symbol': 'AAPL', 'actualEarningResult': 1.68, 'estimatedEarning': 1.41}, {'date': '2020-10-29', 'symbol': 'AAPL', 'actualEarningResult': 0.73, 'estimatedEarning': 0.7}, {'date': '2020-07-30', 'symbol': 'AAPL', 'actualEarningResult': 0.65, 'estimatedEarning': 0.51}, {'date': '2020-04-30', 'symbol': 'AAPL', 'actualEarningResult': 0.64, 'estimatedEarning': 0.56}, {'date': '2020-01-28', 'symbol': 'AAPL', 'actualEarningResult': 1.25, 'estimatedEarning': 1.14}, {'date': '2019-10-30', 'symbol': 'AAPL', 'actualEarningResult': 0.76, 'estimatedEarning': 0.71}, {'date': '2019-07-30', 'symbol': 'AAPL', 'actualEarningResult': 0.55, 'estimatedEarning': 0.53}, {'date': '2019-04-30', 'symbol': 'AAPL', 'actualEarningResult': 0.62, 'estimatedEarning': 0.59}, {'date': '2019-01-29', 'symbol': 'AAPL', 'actualEarningResult': 1.05, 'estimatedEarning': 1.04}, {'date': '2018-11-01', 'symbol': 'AAPL', 'actualEarningResult': 0.73, 'estimatedEarning': 0.7}]

00:00', 'symbol': 'AAPL', 'stocktwitsPosts': 4, 'twitterPosts': 21, 'stocktwitsComments': 0, 'twitterComments': 61, 'stocktwitsLikes': 0, 'twitterLikes': 242, 'stocktwitsImpressions': 2642, 'twitterImpressions': 215213}, {'date': '2021-12-06 02:00:00', 'symbol': 'AAPL', 'stocktwitsPosts': 12, 'twitterPosts': 29, 'stocktwitsComments': 2, 'twitterComments': 87, 'stocktwitsLikes': 10, 'twitterLikes': 465, 'stocktwitsImpressions': 46187, 'twitterImpressions': 109226}, {'date': '2021-12-06 01:00:00', 'symbol': 'AAPL', 'stocktwitsPosts': 11, 'twitterPosts': 23, 'stocktwitsComments': 1, 'twitterComments': 61, 'stocktwitsLikes': 10, 'twitterLikes': 511, 'stocktwitsImpressions': 9101, 'twitterImpressions': 47698}, {'date': '2021-12-06 00:00:00', 'symbol': 'AAPL', 'stocktwitsPosts': 4, 'twitterPosts': 36, 'stocktwitsComments': 0, 'twitterComments': 248, 'stocktwitsLikes': 0, 'twitterLikes': 1491, 'stocktwitsImpressions': 30513, 'twitterImpressions': 95831}, {'date': '2021-12-05 23:00:00', 'symbol': 'AAPL', 'stocktwitsPosts': 22, 'twitterPosts': 71, 'stocktwitsComments': 5, 'twitterComments': 340, 'stocktwitsLikes': 18, 'twitterLikes': 2116, 'stocktwitsImpressions': 19997, 'twitterImpressions': 230919}, {'date': '2021-12-05 22:00:00', 'symbol': 'AAPL', 'stocktwitsPosts': 6, 'twitterPosts': 57, 'stocktwitsComments': 1, 'twitterComments': 1198, 'stocktwitsLikes': 1, 'twitterLikes': 5533, 'stocktwitsImpressions': 23501, 'twitterImpressions': 186052}, {'date': '2021-12-05 21:00:00', 'symbol': 'AAPL', 'stocktwitsPosts' ...

# %%
#connect to  database. It will create database call earnings_surprises
db = client['social_sentiments']

# %%
# 4- Historical Dividends

# %%
historical_dividends = requests.get ('https://financialmodelingprep.com/api/v3/historical-price-full/stock_dividend/AAPL?apikey=9cd6b96b4b472eb298b9178e91959c51')

# %%
historical_dividends = historical_dividends.json()

# %%
print(historical_dividends)
#outcome
# Out:
# {'symbol': 'AAPL', 'historical': [{'date': '2021-11-05', 'label': 'November 05, 21', 'adjDividend': 0.22, 'dividend': 0.22, 'recordDate': '2021-11-08', 'paymentDate': '2021-11-11', 'declarationDate': '2021-10-28'}, {'date': '2021-08-06', 'label': 'August 06, 21', 'adjDividend': 0.22, 'dividend': 0.22, 'recordDate': '2021-08-09', 'paymentDate': '2021-08-12', 'declarationDate': '2021-07-27'}, {'date': '2021-05-07', 'label': 'May 07, 21', 'adjDividend': 0.22, 'dividend': 0.22, 'recordDate': '2021-05-10', 'paymentDate': '2021-05-13', 'declarationDate': '2021-04-28'}, {'date': '2021-02-05', 'label': 'February 05, 21', 'adjDividend': 0.205, 'dividend': 0.205, 'recordDate': '2021-02-08', 'paymentDate': '2021-02-11', 'declarationDate': '2021-01-27'}, {'date': '2020-11-06', 'label': 'November 06, 20', 'adjDividend': 0.205, 'dividend': 0.205, 'recordDate': '2020-11-09', 'paymentDate': '2020-11-12', 'declarationDate': '2020-10-29'}, {'date': '2020-08-07', 'label': 'August 07, 20', 'adjDividend': 0.205, 'dividend': 0.82, 'recordDate': '2020-08-10', 'paymentDate': '2020-08-13', 'declarationDate': '2020-07-30'}, {'date': '2020-05-08', 'label': 'May 08, 20', 'adjDividend': 0.205, 'dividend': 0.82, 'recordDate': '2020-05-11', 'paymentDate': '2020-05-14', 'declarationDate': '2020-04-30'}, {'date': '2020-02-07', 'label': 'February 07, 20', 'adjDividend': 0.1925, 'dividend': 0.77, 'recordDate': '2020-02-10', 'paymentDate': '2020-02-13', 'declarationDate': '2020-01-28'}, {'date': '2019-11-07', 'label': 'November 07, 19', 'adjDividend': 0.1925, 'dividend': 0.77, 'recordDate': '2019-11-11', 'paymentDate': '2019-11-14', 'declarationDate': '2019-10-30'}, {'date': '2019-08-09', 'label': 'August 09, 19', 'adjDividend': 0.1925, 'dividend': 0.77, 'recordDate': '2019-08-12', 'paymentDate': '2019-08-15', 'declarationDate': '2019-07-30'}, {'date': '2019-05-10', 'label': 'May 10, 19', 'adjDividend': 0.1925, 'dividend': 0.77, 'recordDate': '2019-05-13', 'paymentDate': '2019-05-16', 'declarationDate': '2019-05-01'}, {'date': '2019-02-08', 'label': 'February 08, 19', 'adjDividend': 0.1825, 'dividend': 0.73, 'recordDate': '2019-02-11', 'paymentDate': '2019-02-14', 'declarationDate': '2019-01-29'}, {'date': '2018-11-08', 'label': 'November 08, 18', 'adjDividend': 0.1825, 'dividend': 0.73, 'recordDate': '2018-11-12', 'paymentDate': '2018-11-15', 'declarationDate': '2018-11-01'}, {'date': '2018-08-10', 'label': 'August 10, 18', 'adjDividend': 0.1825, 'dividend': 0.73, 'recordDate': '2018-08-13', 'paymentDate': '2018-08-16', 'declarationDate': '2018-07-31'}, {'date': '2018-05-11', 'label': 'May 11, 18', 'adjDividend': 0.1825, 'dividend': 0.73, 'recordDate': '2018-05-14', 'paymentDate': '2018-05-17', 'declarationDate': '2018-05-01'}, {'date': '2018-02-09', 'label': 'February 09, 18', 'adjDividend': 0.1575, 'dividend': 0.63, 'recordDate': '2018-02-12', 'paymentDate': '2018-02-15', 'declarationDate': '2018-02-01'}, {'date': '2017-11-10', 'label': 'November 10, 17', 'adjDividend': 0.1575, 'dividend': 0.63, 'recordDate': '2017-11-13', 'paymentDate': '2017-11-16', 'declarationDate': '2017-11-02'}, {'date': '2017-08-10', 'label': 'August 10, 17', 'adjDividend': 0.1575, 'dividend': 0.63, 'recordDate': '2017-08-14', 'paymentDate': '2017-08-17', 'declarationDate': '2017-08-01'}, {'date': '2017-05-11', 'label': 'May 11, 17', 'adjDividend': 0.1575, 'dividend': 0.63, 'recordDate': '2017-05-15', 'paymentDate': '2017-05-18', 'declarationDate': '2017-05-02'}, {'date': '2017-02-09', 'label': 'February 09, 17', 'adjDividend': 0.1425, 'dividend': 0.57, 'recordDate': '2017-02-13', 'paymentDate': '2017-02-16', 'declarationDate': '2017-02-01'}, {'date': '2016-11-03', 'label': 'November 03, 16', 'adjDividend': 0.1425, 'dividend': 0.57, 'recordDate': '2016-11-07', 'paymentDate': '2016-11-10', 'declarationDate': '2016-10-25'}, {'date': '2016-08-04', 'label': 'August 04, 16', 'adjDividend': 0.1425, 'dividend': 0.57, 'recordDate': '2016-08-08', 'paymentDate': '2016-08-11', 'declarationDate':  ...

# %%
#connect to  database. It will create database call earnings_surprises
db = client['historical_dividends']

# %%
# 5- Multiple companies Prices

# %%
multiple_companies_prices = requests.get('https://financialmodelingprep.com/api/v3/quote/AAPL,FB,GOOG?apikey=9cd6b96b4b472eb298b9178e91959c51')

# %%
multiple_companies_prices = multiple_companies_prices.json()

# %%
print(multiple_companies_prices)
#outcome
# Out:
# [{'symbol': 'AAPL', 'name': 'Apple Inc.', 'price': 176.405, 'changesPercentage': 1.0569439, 'change': 1.8450012, 'dayLow': 174.7, 'dayHigh': 176.99, 'yearHigh': 176.99, 'yearLow': 116.21, 'marketCap': 2894170947584.0, 'priceAvg50': 151.6498, 'priceAvg200': 139.6428, 'volume': 45886985, 'avgVolume': 84530382, 'exchange': 'NASDAQ', 'open': 175.205, 'previousClose': 174.56, 'eps': 5.61, 'pe': 31.44474, 'earningsAnnouncement': '2022-01-25T21:00:00.000+0000', 'sharesOutstanding': 16406399748, 'timestamp': 1639154857}, {'symbol': 'FB', 'name': 'Meta Platforms, Inc.', 'price': 329.99, 'changesPercentage': 0.05153808, 'change': 0.16998291, 'dayLow': 326.37, 'dayHigh': 335.0, 'yearHigh': 384.33, 'yearLow': 244.61, 'marketCap': 917952987136.0, 'priceAvg50': 330.9434, 'priceAvg200': 329.8933, 'volume': 6714716, 'avgVolume': 23125704, 'exchange': 'NASDAQ', 'open': 332.555, 'previousClose': 329.82, 'eps': 13.974, 'pe': 23.614569, 'earningsAnnouncement': '2022-01-25T10:59:00.000+0000', 'sharesOutstanding': 2781760014, 'timestamp': 1639154857}, {'symbol': 'GOOG', 'name': 'Alphabet Inc.', 'price': 2963.57, 'changesPercentage': 0.04894978, 'change': 1.4499512, 'dayLow': 2948.0024, 'dayHigh': 2988.0, 'yearHigh': 3037.0, 'yearLow': 1699.0, 'marketCap': 1963874844672.0, 'priceAvg50': 2872.704, 'priceAvg200': 2581.8362, 'volume': 373869, 'avgVolume': 1169854, 'exchange': 'NASDAQ', 'open': 2982.0, 'previousClose': 2962.12, 'eps': 103.805, 'pe': 28.549397, 'earningsAnnouncement': None, 'sharesOutstanding': 662671995, 'timestamp': 1639154857}]

# %%
#connect to  database. It will create database call multiple_companies_prices
db = client ['multiple_companies_prices']

# %% [markdown]
# # SAGAR'S CODE

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\sandelemental\anaconda3\lib\site-packages (0.1.67)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: requests>=2.20 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: pandas>=0.24 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (1.3.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sandelemental\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\sandelemental\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
stock_info = yf.Ticker('TSLA').info
# stock_info.keys() for other properties you can explore

# %%
market_price = stock_info['regularMarketPrice']
previous_close_price = stock_info['regularMarketPreviousClose']

# %%
print('market price ', market_price)
print('previous close price ', previous_close_price)
# Out:
# market price  1068.96
# previous close price  1051.75

# %%
# Install yfinance and matplotlib package
# !pip install yfinance
# !pip install matplotlib
# Import yfinance and matplotlib
import yfinance as yf  
import matplotlib.pyplot as plt
# Get the data for the SPY ETF by specifying the stock ticker, start date, and end date
data = yf.download('SPY','2015-01-01','2020-01-01')
# Plot the close prices
data["Adj Close"].plot()
plt.show()
# Out:
# Requirement already satisfied: yfinance in c:\users\sandelemental\anaconda3\lib\site-packages (0.1.67)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (1.3.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (1.20.3)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: requests>=2.20 in c:\users\sandelemental\anaconda3\lib\site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sandelemental\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\sandelemental\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2.0.4)
# Requirement already satisfied: matplotlib in c:\users\sandelemental\anaconda3\lib\site-packages (3.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\sandelemental\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sandelemental\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.16 in c:\users\sandelemental\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six in c:\users\sandelemental\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# [*********************100%***********************]  1 of 1 completed

# %%
# Install quandl package
# !pip install quandl
# Import quandl
import quandl
# Get the data for Coca-cola
data = quandl.get("WIKI/KO", start_date="2015-01-01", end_date="2021-10-01", api_key="u8toFrUNkj9z9utuuU3s")
# Plot the prices
data.Close.plot()
plt.show()
# Out:
# Requirement already satisfied: quandl in c:\users\sandelemental\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: requests>=2.7.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from quandl) (2.26.0)
# Requirement already satisfied: pandas>=0.14 in c:\users\sandelemental\anaconda3\lib\site-packages (from quandl) (1.3.3)
# Requirement already satisfied: python-dateutil in c:\users\sandelemental\anaconda3\lib\site-packages (from quandl) (2.8.2)
# Requirement already satisfied: numpy>=1.8 in c:\users\sandelemental\anaconda3\lib\site-packages (from quandl) (1.20.3)
# Requirement already satisfied: more-itertools in c:\users\sandelemental\anaconda3\lib\site-packages (from quandl) (8.8.0)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from quandl) (0.5.1)
# Requirement already satisfied: six in c:\users\sandelemental\anaconda3\lib\site-packages (from quandl) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sandelemental\anaconda3\lib\site-packages (from pandas>=0.14->quandl) (2021.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2.0.4)

# %%
pip install polygon-api-client
# Out:
# Requirement already satisfied: polygon-api-client in c:\users\sandelemental\anaconda3\lib\site-packages (0.2.11)
# Requirement already satisfied: requests>=2.22.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from polygon-api-client) (2.26.0)
# Requirement already satisfied: websocket-client>=0.56.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from polygon-api-client) (1.2.3)
# Requirement already satisfied: websockets>=8.0.2 in c:\users\sandelemental\anaconda3\lib\site-packages (from polygon-api-client) (9.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.22.0->polygon-api-client) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.22.0->polygon-api-client) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.22.0->polygon-api-client) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.22.0->polygon-api-client) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import time

from polygon import WebSocketClient, STOCKS_CLUSTER


def my_custom_process_message(message):
    print("this is my custom message processing", message)


def my_custom_error_handler(ws, error):
    print("this is my custom error handler", error)


def my_custom_close_handler(ws):
    print("this is my custom close handler")


def main():
    key = 'your api key'
    my_client = WebSocketClient(STOCKS_CLUSTER, key, my_custom_process_message)
    my_client.run_async()

    my_client.subscribe("T.MSFT", "T.AAPL", "T.AMD", "T.NVDA")
    time.sleep(1)

    my_client.close_connection()


if __name__ == "__main__":
    main()
# Out:
# this is my custom message processing [{"ev":"status","status":"connected","message":"Connected Successfully"}]
# this is my custom message processing [{"ev":"status","status":"auth_failed","message":"authentication failed"}]

# %%
from polygon import RESTClient


def main():
    key = "52ZpjCm5Cqaoc0ZARZ4LB_LOXmLhDDSq"

    # RESTClient can be used as a context manager to facilitate closing the underlying http session
    # https://requests.readthedocs.io/en/master/user/advanced/#session-objects
    with RESTClient(key) as client:
        resp = client.stocks_equities_daily_open_close("AAPL", "2021-06-11")
        print(f"On: {resp.from_} Apple opened at {resp.open} and closed at {resp.close}")


if __name__ == '__main__':
    main()
# Out:
# On: 2021-06-11 Apple opened at 126.53 and closed at 127.35

# %%
import datetime

from polygon import RESTClient


def ts_to_datetime(ts) -> str:
    return datetime.datetime.fromtimestamp(ts / 1000.0).strftime('%Y-%m-%d %H:%M')


def main():
    key = "52ZpjCm5Cqaoc0ZARZ4LB_LOXmLhDDSq"

    # RESTClient can be used as a context manager to facilitate closing the underlying http session
    # https://requests.readthedocs.io/en/master/user/advanced/#session-objects
    with RESTClient(key) as client:
        from_ = "2021-01-01"
        to = "2021-02-01"
        resp = client.stocks_equities_aggregates("AAPL", 1, "minute", from_, to, unadjusted=False)

        print(f"Minute aggregates for {resp.ticker} between {from_} and {to}.")

        for result in resp.results:
            dt = ts_to_datetime(result["t"])
            print(f"{dt}\n\tO: {result['o']}\n\tH: {result['h']}\n\tL: {result['l']}\n\tC: {result['c']} ")


if __name__ == '__main__':
    main()
# Out:
# Minute aggregates for AAPL between 2021-01-01 and 2021-02-01.
# 2021-01-04 04:00
# 	O: 133.31
# 	H: 133.49
# 	L: 133.02
# 	C: 133.49
# 2021-01-04 04:01
# 	O: 133.49
# 	H: 133.49
# 	L: 133.49
# 	C: 133.49
# 2021-01-04 04:02
# 	O: 133.6
# 	H: 133.6
# 	L: 133.5
# 	C: 133.5
# 2021-01-04 04:03
# 	O: 133.51
# 	H: 133.51
# 	L: 133.51
# 	C: 133.51
# 2021-01-04 04:04
# 	O: 133.77
# 	H: 133.77
# 	L: 133.7
# 	C: 133.72
# 2021-01-04 04:05
# 	O: 133.71
# 	H: 133.74
# 	L: 133.71
# 	C: 133.74
# 2021-01-04 04:06
# 	O: 133.75
# 	H: 133.76
# 	L: 133.72
# 	C: 133.72
# 2021-01-04 04:07
# 	O: 133.77
# 	H: 133.85
# 	L: 133.77
# 	C: 133.8
# 2021-01-04 04:08
# 	O: 133.89
# 	H: 133.9
# 	L: 133.89
# 	C: 133.9
# 2021-01-04 04:09
# 	O: 133.89
# 	H: 133.98
# 	L: 133.89
# 	C: 133.98
# 2021-01-04 04:10
# 	O: 133.98
# 	H: 133.98
# 	L: 133.98
# 	C: 133.98
# 2021-01-04 04:11
# 	O: 133.97
# 	H: 134
# 	L: 133.96
# 	C: 133.96
# 2021-01-04 04:12
# 	O: 133.93
# 	H: 133.93
# 	L: 133.9
# 	C: 133.9
# 2021-01-04 04:13
# 	O: 133.89
# 	H: 133.89
# 	L: 133.85
# 	C: 133.85
# 2021-01-04 04:14
# 	O: 133.82
# 	H: 133.82
# 	L: 133.74
# 	C: 133.74
# 2021-01-04 04:16
# 	O: 133.98
# 	H: 134
# 	L: 133.98
# 	C: 134
# 2021-01-04 04:17
# 	O: 134
# 	H: 134.01
# 	L: 133.96
# 	C: 134
# 2021-01-04 04:18
# 	O: 134
# 	H: 134
# 	L: 133.96
# 	C: 133.96
# 2021-01-04 04:19
# 	O: 133.94
# 	H: 133.95
# 	L: 133.94
# 	C: 133.95
# 2021-01-04 04:20
# 	O: 133.9
# 	H: 133.95
# 	L: 133.9
# 	C: 133.9
# 2021-01-04 04:21
# 	O: 129.59
# 	H: 129.624
# 	L: 129.53
# 	C: 129.5577
# 2021-01-11 13:27
# 	O: 129.54
# 	H: 129.59
# 	L: 129.48
# 	C: 129.4824
# 2021-01-11 13:28
# 	O: 129.48
# 	H: 129.57
# 	L: 129.45
# 	C: 129.5488
# 2021-01-11 13:29
# 	O: 129.55
# 	H: 129.615
# 	L: 129.53
# 	C: 129.61
# 2021-01-11 13:30
# 	O: 129.62
# 	H: 129.65
# 	L: 129.54
# 	C: 129.6108
# 2021-01-11 13:31
# 	O: 129.62
# 	H: 129.62
# 	L: 129.52
# 	C: 129.5201
# 2021-01-11 13:32
# 	O: 129.52
# 	H: 129.5375
# 	L: 129.45
# 	C: 129.51
# 2021-01-11 13:33
# 	O: 129.51
# 	H: 129.53
# 	L: 129.46
# 	C: 129.5
# 2021-01-11 13:34
# 	O: 129.505
# 	H: 129.6
# 	L: 129.49
# 	C: 129.5627
# 2021-01-11 13:35
# 	O: 129.56
# 	H: 129.59
# 	L: 129.46
# 	C: 129.4601
# 2021-01-11 13:36
# 	O: 129.465
# 	H: 129.5085
# 	L: 129.44
# 	C: 129.47
# 2021-01-11 13:37
# 	O: 129.4742
# 	H: 129.49
# 	L: 129.45
# 	C: 129.469
# 2021-01-11 13:38
# 	O: 129.47
# 	H: 129.4999
# 	L: 129.4
# 	C: 129.4901
# 2021-01-11 13:39
# 	O: 129.4857
# 	H: 129.5
# 	L: 129.46
# 	C: 129.465
# 2021-01-11 13:40
# 	O: 129.463
# 	H: 129.47
# 	L: 129.3
# 	C: 129.36
# 2021-01-11 13:41
# 	O: 129.3568
# 	H: 129.415
# 	L: 129.34
# 	C: 129.3993
# 2021-01-11 13:42
# 	O: 129.395
# 	H: 129.4047
# 	L: 129.31
# 	C: 129.4
# 2021-01-11 13:43
# 	O: 129.4
# 	H: 129.53
# 	L: 129.3908
# 	C: 129.485
# 2021-01-11 13:44
# 	O: 129.4859
# 	H: 129.54
# 	L: 129.425
# 	C: 129.4715
# 2021-01-11 13:45
# 	O: 129.4777
# 	H: 129.5
# 	L: 129.4
# 	C: 129.44
# 2021-01-11 13:46
# 	O: 129.44
# 	H: 129.44
# 	L: 129.27
# 	C: 129.31
# 2021-01-11 13:47
# 	O: 129.31
# 	H: 129.38
# 	L: 129.31
# 	C: 129.35
# 2021-01-11 13:48
# 	O: 129.36
# 	H: 129.38
# 	L: 129.2801
# 	C: 129.31

# %%
import yfinance as yf #Allows us to Use Yahoo Finance API 
import pandas as pd
import numpy as np

# %%
def ticker_info():
    ticker_name = input("Enter Ticker Name")
    ticker_symbol = yf.Ticker(ticker_name)
    ticker_data = ticker_symbol.history(period="max")
    return ticker_data

# %%
ticker_info()
# Out:
# Enter Ticker Name AMZN
#                    Open         High          Low        Close    Volume  \
# Date
# 1997-05-15     2.437500     2.500000     1.927083     1.958333  72156000
# 1997-05-16     1.968750     1.979167     1.708333     1.729167  14700000
# 1997-05-19     1.760417     1.770833     1.625000     1.708333   6106800
# 1997-05-20     1.729167     1.750000     1.635417     1.635417   5467200
# 1997-05-21     1.635417     1.645833     1.375000     1.427083  18853200
# ...                 ...          ...          ...          ...       ...
# 2021-12-01  3545.000000  3559.879883  3441.600098  3443.719971   3745800
# 2021-12-02  3460.000000  3492.699951  3423.750000  3437.360107   3236300
# 2021-12-03  3455.000000  3469.870117  3338.600098  3389.790039   4032600
# 2021-12-06  3393.000000  3473.909912  3338.689941  3427.370117   3443000
# 2021-12-07  3492.000000  3549.989990  3466.689941  3523.290039   3320536
#
#             Dividends  Stock Splits
# Date
# 1997-05-15          0           0.0
# 1997-05-16          0           0.0
# 1997-05-19          0           0.0
# 1997-05-20          0           0.0
# 1997-05-21          0           0.0
# ...               ...           ...
# 2021-12-01          0           0.0
# 2021-12-02          0           0.0
# 2021-12-03          0           0.0
# 2021-12-06          0           0.0
# 2021-12-07          0           0.0
#
# [6183 rows x 7 columns]

# %%
# !pip install polygon-api-client
# Out:
# Requirement already satisfied: polygon-api-client in c:\users\sandelemental\anaconda3\lib\site-packages (0.2.11)
# Requirement already satisfied: websockets>=8.0.2 in c:\users\sandelemental\anaconda3\lib\site-packages (from polygon-api-client) (9.1)
# Requirement already satisfied: requests>=2.22.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from polygon-api-client) (2.26.0)
# Requirement already satisfied: websocket-client>=0.56.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from polygon-api-client) (1.2.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.22.0->polygon-api-client) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.22.0->polygon-api-client) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.22.0->polygon-api-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests>=2.22.0->polygon-api-client) (3.2)

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=E0J9A9XWOHRT0UIC'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'IBM', '3. Last Refreshed': '2021-12-07 19:55:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2021-12-07 19:55:00': {'1. open': '121.7000', '2. high': '121.7000', '3. low': '121.7000', '4. close': '121.7000', '5. volume': '200'}, '2021-12-07 19:45:00': {'1. open': '121.6100', '2. high': '121.6100', '3. low': '121.6100', '4. close': '121.6100', '5. volume': '300'}, '2021-12-07 19:10:00': {'1. open': '121.8200', '2. high': '121.8200', '3. low': '121.8200', '4. close': '121.8200', '5. volume': '200'}, '2021-12-07 19:00:00': {'1. open': '122.2000', '2. high': '122.2000', '3. low': '122.2000', '4. close': '122.2000', '5. volume': '200'}, '2021-12-07 17:50:00': {'1. open': '121.9100', '2. high': '121.9100', '3. low': '121.9000', '4. close': '121.9000', '5. volume': '503'}, '2021-12-07 17:45:00': {'1. open': '122.0000', '2. high': '122.2000', '3. low': '122.0000', '4. close': '122.2000', '5. volume': '937'}, '2021-12-07 17:40:00': {'1. open': '122.0000', '2. high': '122.0000', '3. low': '122.0000', '4. close': '122.0000', '5. volume': '708'}, '2021-12-07 17:30:00': {'1. open': '122.0000', '2. high': '122.0000', '3. low': '122.0000', '4. close': '122.0000', '5. volume': '110'}, '2021-12-07 17:05:00': {'1. open': '121.9900', '2. high': '122.0000', '3. low': '121.9900', '4. close': '122.0000', '5. volume': '500'}, '2021-12-07 17:00:00': {'1. open': '122.0000', '2. high': '122.0000', '3. low': '121.9100', '4. close': '121.9100', '5. volume': '634'}, '2021-12-07 16:45:00': {'1. open': '121.9600
https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=tesco&apikey=E0J9A9XWOHRT0UIC'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'bestMatches': [{'1. symbol': 'TSCO.LON', '2. name': 'Tesco PLC', '3. type': 'Equity', '4. region': 'United Kingdom', '5. marketOpen': '08:00', '6. marketClose': '16:30', '7. timezone': 'UTC+00', '8. currency': 'GBX', '9. matchScore': '0.7273'}, {'1. symbol': 'TSCDF', '2. name': 'Tesco plc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7143'}, {'1. symbol': 'TSCDY', '2. name': 'Tesco plc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7143'}]}

# %%
pip install alpha_vantage
# Out:
# Requirement already satisfied: alpha_vantage in c:\users\sandelemental\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: requests in c:\users\sandelemental\anaconda3\lib\site-packages (from alpha_vantage) (2.26.0)
# Requirement already satisfied: aiohttp in c:\users\sandelemental\anaconda3\lib\site-packages (from alpha_vantage) (3.7.4.post0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (21.2.0)
# Requirement already satisfied: chardet<5.0,>=2.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (4.0.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (5.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (3.10.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (1.7.0)
# Requirement already satisfied: idna>=2.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->alpha_vantage) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests->alpha_vantage) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests->alpha_vantage) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests->alpha_vantage) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install alpha_vantage pandas
# Out:
# Requirement already satisfied: alpha_vantage in c:\users\sandelemental\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: pandas in c:\users\sandelemental\anaconda3\lib\site-packages (1.3.3)
# Requirement already satisfied: aiohttp in c:\users\sandelemental\anaconda3\lib\site-packages (from alpha_vantage) (3.7.4.post0)
# Requirement already satisfied: requests in c:\users\sandelemental\anaconda3\lib\site-packages (from alpha_vantage) (2.26.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\sandelemental\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sandelemental\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sandelemental\anaconda3\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (1.7.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (3.0.1)
# Requirement already satisfied: chardet<5.0,>=2.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (4.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (3.10.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (5.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (21.2.0)
# Requirement already satisfied: idna>=2.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->alpha_vantage) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests->alpha_vantage) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests->alpha_vantage) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sandelemental\anaconda3\lib\site-packages (from requests->alpha_vantage) (1.26.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='E0J9A9XWOHRT0UIC')
# Get json object with the intraday data and another with  the call's metadata
data, meta_data = ts.get_intraday('GOOGL')

# %%
from alpha_vantage.timeseries import TimeSeries
from pprint import pprint
ts = TimeSeries(key='E0J9A9XWOHRT0UIC', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
pprint(data.head(2))
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2021-12-07 20:00:00   335.85   335.93  335.85    335.93      925.0
# 2021-12-07 19:59:00   335.80   335.84  335.80    335.84     1232.0

# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt

ts = TimeSeries(key='E0J9A9XWOHRT0UIC', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
pip install nest-asyncio
# Out:
# Requirement already satisfied: nest-asyncio in c:\users\sandelemental\anaconda3\lib\site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import asyncio
nest_asyncio.apply()
from alpha_vantage.async_support.timeseries import TimeSeries

symbols = ['MSFT', 'AAPL', 'TSLA', 'SONY', 'MCD']


async def get_data(symbol):
    ts = TimeSeries(key='E0J9A9XWOHRT0UIC')
    data, _ = await ts.get_quote_endpoint(symbol)
    await ts.close()
    return data

loop = asyncio.get_event_loop()
tasks = [get_data(symbol) for symbol in symbols]
group1 = asyncio.gather(*tasks)
results = loop.run_until_complete(loop.shutdown_asyncgens(group1))
loop.close()
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/101881479.py in <module>
#       1 import asyncio
# ----> 2 nest_asyncio.apply()
#       3 from alpha_vantage.async_support.timeseries import TimeSeries
#       4
#       5 symbols = ['MSFT', 'AAPL', 'TSLA', 'SONY', 'MCD']
#
# NameError: name 'nest_asyncio' is not defined

# %%
import asyncio
from alpha_vantage.async_support.timeseries import TimeSeries

symbols = ['AAPL', 'GOOG', 'TSLA', 'MSFT']


async def get_data(symbol):
    ts = TimeSeries(key='E0J9A9XWOHRT0UIC')
    data, _ = await ts.get_quote_endpoint(symbol)
    await ts.close()
    return data

loop = asyncio.get_event_loop()
tasks = [get_data(symbol) for symbol in symbols]
group1 = asyncio.gather(*tasks)
results = loop.run_until_complete(group1)
loop.close()
print(results)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/3337924592.py in <module>
#      14 tasks = [get_data(symbol) for symbol in symbols]
#      15 group1 = asyncio.gather(*tasks)
# ---> 16 results = loop.run_until_complete(group1)
#      17 loop.close()
#      18 print(results)
#
# ~\anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     590         """
#     591         self._check_closed()
# --> 592         self._check_running()
#     593
#     594         new_task = not futures.isfuture(future)
#
# ~\anaconda3\lib\asyncio\base_events.py in _check_running(self)
#     550     def _check_running(self):
#     551         if self.is_running():
# --> 552             raise RuntimeError('This event loop is already running')
#     553         if events._get_running_loop() is not None:
#     554             raise RuntimeError(
#
# RuntimeError: This event loop is already running

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=AAPL&apikey=E0J9A9XWOHRT0UIC'
rAAPL = requests.get(url)
AAPL = rAAPL.json()

print(AAPL)
# Out:
# {'Note': 'Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.'}

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=MSFT&apikey=E0J9A9XWOHRT0UIC'
rMSFT = requests.get(url)
MSFT = rMSFT.json()

print(MSFT)
# Out:
# {'Note': 'Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.'}

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=TSLA&apikey=E0J9A9XWOHRT0UIC'
rTSLA = requests.get(url)
TSLA = rTSLA.json()

print(TSLA)
# Out:
# {'Note': 'Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.'}

# %%
price_df = pd.concat([TSLA, MSFT, AAPL], axis=1, join="inner")

price_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SANDEL~1\AppData\Local\Temp/ipykernel_3680/1438357647.py in <module>
# ----> 1 price_df = pd.concat([TSLA, MSFT, AAPL], axis=1, join="inner")
#       2
#       3 price_df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     382                     "only Series and DataFrame objs are valid"
#     383                 )
# --> 384                 raise TypeError(msg)
#     385
#     386             ndims.add(obj.ndim)
#
# TypeError: cannot concatenate object of type '<class 'dict'>'; only Series and DataFrame objs are valid
